# %%
import glob
import os
import librosa
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# Path to the metadata file
metadata_file_path = r'D:\download\Compressed\DF-keys-full\keys\DF\CM\trial_metadata.txt'

# Dictionary to hold file identifiers and labels
labels = {}
with open(metadata_file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        file_identifier = parts[1]
        label = parts[5]
        labels[file_identifier] = label

# Directory containing the undersampled audio files
undersampled_audio_dir = r'D:\audio_files\undersampled_audio'
audio_files = glob.glob(os.path.join(undersampled_audio_dir, '*.flac'))

valid_audio_files = []
valid_labels = []

for audio_file in audio_files:
    file_name = os.path.basename(audio_file)
    file_identifier = file_name.split('.')[0]
    if file_identifier in labels:
        valid_audio_files.append(audio_file)
        valid_labels.append(labels[file_identifier])

print(f"Found {len(valid_audio_files)} audio files with corresponding labels.")

# Audio to MFCC conversion function
def audio_to_mfcc(audio_file, sr=22050, n_mfcc=13):
    audio, sample_rate = librosa.load(audio_file, sr=sr)
    mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    return mfcc

def pad_or_truncate(mfcc, max_time_steps=400):
    if mfcc.shape[1] > max_time_steps:
        return mfcc[:, :max_time_steps]
    elif mfcc.shape[1] < max_time_steps:
        padding = max_time_steps - mfcc.shape[1]
        return np.pad(mfcc, ((0, 0), (0, padding)), mode='constant')
    return mfcc

# Preprocessing function with normalization
def preprocess_audio_files_rnn(audio_files, labels, n_mfcc=13, max_time_steps=400):
    mfcc_data = []
    label_data = []
    scaler = StandardScaler()
    
    for audio_file, label in zip(audio_files, labels):
        mfcc = audio_to_mfcc(audio_file, n_mfcc=n_mfcc)
        mfcc = pad_or_truncate(mfcc, max_time_steps=max_time_steps).T
        mfcc = scaler.fit_transform(mfcc)
        mfcc_data.append(mfcc)
        label_data.append(1 if label == 'spoof' else 0)

    return np.array(mfcc_data), np.array(label_data)

X, y = preprocess_audio_files_rnn(valid_audio_files, valid_labels)
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

def stratified_split_70_30(X, y, test_size=0.2, random_state=42):
    strat_split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    for train_idx, test_idx in strat_split.split(X, y):
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = stratified_split_70_30(X, y)
print(f"Training set distribution: {np.bincount(y_train)}")
print(f"Test set distribution: {np.bincount(y_test)}")

def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)
rnn_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Found 45234 audio files with corresponding labels.
# Shape of X: (45234, 400, 13)
# Shape of y: (45234,)
# Training set distribution: [18093 18094]
# Test set distribution: [4524 4523]
# Epoch 1/50
# 453/453 [==============================] - 186s 367ms/step - loss: 0.5597 - accuracy: 0.7249 - val_loss: 0.4940 - val_accuracy: 0.7691
# Epoch 2/50
# 453/453 [==============================] - 162s 358ms/step - loss: 0.5058 - accuracy: 0.7672 - val_loss: 0.4657 - val_accuracy: 0.7868
# Epoch 3/50
# 453/453 [==============================] - 163s 359ms/step - loss: 0.4830 - accuracy: 0.7800 - val_loss: 0.4469 - val_accuracy: 0.7939
# Epoch 4/50
# 453/453 [==============================] - 217s 478ms/step - loss: 0.4723 - accuracy: 0.7818 - val_loss: 0.4390 - val_accuracy: 0.8017
# Epoch 5/50
# 453/453 [==============================] - 117s 258ms/step - loss: 0.4608 - accuracy: 0.7865 - val_loss: 0.4309 - val_accuracy: 0.7998
# Epoch 6/50
# 453/453 [==============================] - 84s 185ms/step - loss: 0.4485 - accuracy: 0.7916 - val_loss: 0.4250 - val_accuracy: 0.8009
# Epoch 7/50
# 453/453 [==============================] - 76s 168ms/step - loss: 0.4439 - accuracy: 0.7952 - val_loss: 0.4210 - val_accuracy: 0.8044
# Epoch 8/50
# 453/453 [==============================] - 70s 154ms/step - loss: 0.4296 - accuracy: 0.7962 - val_loss: 0.4105 - val_accuracy: 0.8092
# Epoch 9/50
# 453/453 [==============================] - 88s 194ms/step - loss: 0.4220 - accuracy: 0.8012 - val_loss: 0.4494 - val_accuracy: 0.7935
# Epoch 10/50
# 453/453 [==============================] - 94s 207ms/step - loss: 0.4174 - accuracy: 0.8042 - val_loss: 0.4073 - val_accuracy: 0.8135
# Epoch 11/50
# 453/453 [==============================] - 85s 188ms/step - loss: 0.4089 - accuracy: 0.8090 - val_loss: 0.3960 - val_accuracy: 0.8203
# Epoch 12/50
# 453/453 [==============================] - 107s 237ms/step - loss: 0.4006 - accuracy: 0.8104 - val_loss: 0.3995 - val_accuracy: 0.8189
# Epoch 13/50
# 453/453 [==============================] - 121s 267ms/step - loss: 0.3982 - accuracy: 0.8116 - val_loss: 0.4101 - val_accuracy: 0.8132
# Epoch 14/50
# 453/453 [==============================] - 131s 289ms/step - loss: 0.3870 - accuracy: 0.8158 - val_loss: 0.4027 - val_accuracy: 0.8145
# 453/453 [==============================] - 164s 363ms/step - loss: 0.3172 - accuracy: 0.8559 - val_loss: 0.3921 - val_accuracy: 0.8250
# Epoch 35/50
# 453/453 [==============================] - 164s 362ms/step - loss: 0.3158 - accuracy: 0.8544 - val_loss: 0.3320 - val_accuracy: 0.8426
# Epoch 36/50
# 453/453 [==============================] - 164s 363ms/step - loss: 0.3075 - accuracy: 0.8608 - val_loss: 0.3549 - val_accuracy: 0.8350
# Epoch 37/50
# 453/453 [==============================] - 164s 362ms/step - loss: 0.3150 - accuracy: 0.8558 - val_loss: 0.3279 - val_accuracy: 0.8483
# Epoch 38/50
# 453/453 [==============================] - 164s 362ms/step - loss: 0.3041 - accuracy: 0.8620 - val_loss: 0.3323 - val_accuracy: 0.8506
# Epoch 39/50
# 453/453 [==============================] - 162s 358ms/step - loss: 0.2972 - accuracy: 0.8671 - val_loss: 0.3420 - val_accuracy: 0.8515
# Epoch 40/50
# 453/453 [==============================] - 164s 362ms/step - loss: 0.3522 - accuracy: 0.8423 - val_loss: 0.3594 - val_accuracy: 0.8279
# Epoch 41/50
# 453/453 [==============================] - 165s 364ms/step - loss: 0.3330 - accuracy: 0.8469 - val_loss: 0.3322 - val_accuracy: 0.8450
# Epoch 42/50
# 453/453 [==============================] - 163s 360ms/step - loss: 0.3159 - accuracy: 0.8562 - val_loss: 0.3415 - val_accuracy: 0.8443
# Test Loss: 0.3290
# Test Accuracy: 0.8469
# 283/283 [==============================] - 36s 118ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      4524
#            1       0.88      0.81      0.84      4523
#
#     accuracy                           0.85      9047
#    macro avg       0.85      0.85      0.85      9047
# weighted avg       0.85      0.85      0.85      9047
#
#
# Confusion Matrix:
# [[4003  521]
#  [ 864 3659]]

# %%
pip install protobuf==3.20.*
# Out:
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl.metadata (698 bytes)
# Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    ---------------------- --------------- 524.3/904.0 kB 161.3 kB/s eta 0:00:03
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    --------------------------------- ---- 786.4/904.0 kB 112.6 kB/s eta 0:00:02
#    -------------------------------------- 904.0/904.0 kB 106.1 kB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.2
#     Uninstalling protobuf-5.29.2:
#       Successfully uninstalled protobuf-5.29.2
# Successfully installed protobuf-3.20.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Hariz\anaconda3\envs\py310\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)

# Compile the model
rnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 400, 128)          54912
#
#  dropout_4 (Dropout)         (None, 400, 128)          0
#
#  batch_normalization_2 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_1 (GRU)                 (None, 400, 64)           37248
#
#  dropout_5 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_3 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 155s 315ms/step - loss: 0.5510 - accuracy: 0.7365 - val_loss: 0.5019 - val_accuracy: 0.7679
# Epoch 2/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.5053 - accuracy: 0.7625 - val_loss: 0.4765 - val_accuracy: 0.7795
# Epoch 3/100
# 453/453 [==============================] - 144s 317ms/step - loss: 0.4684 - accuracy: 0.7820 - val_loss: 0.4165 - val_accuracy: 0.8084
# Epoch 4/100
# 453/453 [==============================] - 141s 311ms/step - loss: 0.4093 - accuracy: 0.8170 - val_loss: 0.3331 - val_accuracy: 0.8562
# Epoch 5/100
# 453/453 [==============================] - 144s 319ms/step - loss: 0.3287 - accuracy: 0.8613 - val_loss: 0.2736 - val_accuracy: 0.8878
# Epoch 6/100
# 453/453 [==============================] - 142s 313ms/step - loss: 0.2542 - accuracy: 0.8972 - val_loss: 0.2144 - val_accuracy: 0.9137
# Epoch 7/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.1970 - accuracy: 0.9256 - val_loss: 0.1783 - val_accuracy: 0.9313
# Epoch 8/100
# 453/453 [==============================] - 143s 316ms/step - loss: 0.1552 - accuracy: 0.9437 - val_loss: 0.1813 - val_accuracy: 0.9284
# Epoch 9/100
# 453/453 [==============================] - 141s 310ms/step - loss: 0.1250 - accuracy: 0.9571 - val_loss: 0.1159 - val_accuracy: 0.9592
# Epoch 10/100
# 453/453 [==============================] - 144s 318ms/step - loss: 0.0950 - accuracy: 0.9678 - val_loss: 0.1660 - val_accuracy: 0.9501
# Epoch 11/100
# 453/453 [==============================] - 141s 311ms/step - loss: 0.0778 - accuracy: 0.9744 - val_loss: 0.1352 - val_accuracy: 0.9591
# Epoch 12/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0667 - accuracy: 0.9782 - val_loss: 0.1189 - val_accuracy: 0.9673
# Epoch 13/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0582 - accuracy: 0.9815 - val_loss: 0.1045 - val_accuracy: 0.9692
# Epoch 14/100
# 453/453 [==============================] - 141s 312ms/step - loss: 0.0473 - accuracy: 0.9845 - val_loss: 0.1014 - val_accuracy: 0.9713
# Epoch 15/100
# 453/453 [==============================] - 144s 317ms/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.1221 - val_accuracy: 0.9688
# Epoch 16/100
# 453/453 [==============================] - 141s 312ms/step - loss: 0.0384 - accuracy: 0.9878 - val_loss: 0.1253 - val_accuracy: 0.9682
# Epoch 17/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.0859 - val_accuracy: 0.9771
# Epoch 18/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0304 - accuracy: 0.9895 - val_loss: 0.1118 - val_accuracy: 0.9743
# Epoch 19/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.2213 - val_accuracy: 0.9563
# Epoch 20/100
# 453/453 [==============================] - 143s 316ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.0815 - val_accuracy: 0.9798
# Epoch 21/100
# 453/453 [==============================] - 140s 310ms/step - loss: 0.0232 - accuracy: 0.9918 - val_loss: 0.1575 - val_accuracy: 0.9627
# Epoch 22/100
# 453/453 [==============================] - 143s 315ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.1203 - val_accuracy: 0.9726
# Epoch 23/100
# 453/453 [==============================] - 142s 313ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.0967 - val_accuracy: 0.9798
# Epoch 24/100
# 453/453 [==============================] - 141s 312ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0945 - val_accuracy: 0.9769
# Epoch 25/100
# 453/453 [==============================] - 143s 315ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.1239 - val_accuracy: 0.9739
# Epoch 26/100
# 453/453 [==============================] - 141s 311ms/step - loss: 0.0242 - accuracy: 0.9929 - val_loss: 0.0918 - val_accuracy: 0.9765
# Epoch 27/100
# 453/453 [==============================] - 143s 316ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.1324 - val_accuracy: 0.9758
# Epoch 28/100
# 453/453 [==============================] - 141s 312ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.0945 - val_accuracy: 0.9778
# Epoch 29/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.1172 - val_accuracy: 0.9753
# Epoch 30/100
# 453/453 [==============================] - 142s 314ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0936 - val_accuracy: 0.9791
# Test Loss: 0.0912
# Test Accuracy: 0.9792
# 283/283 [==============================] - 27s 90ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4524
#            1       0.99      0.96      0.98      4523
#
#     accuracy                           0.98      9047
#    macro avg       0.98      0.98      0.98      9047
# weighted avg       0.98      0.98      0.98      9047
#
#
# Confusion Matrix:
# [[4498   26]
#  [ 162 4361]]

# %% [markdown]
# LTSM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn2_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn2_model = build_rnn2_model(input_shape)

# Compile the model
rnn2_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn2_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn2_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn2_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn2_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 400, 128)          72704
#
#  dropout_12 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_6 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  lstm_7 (LSTM)               (None, 400, 64)           49408
#
#  dropout_13 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_7 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  lstm_8 (LSTM)               (None, 32)                12416
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 88s 161ms/step - loss: 0.5581 - accuracy: 0.7295 - val_loss: 0.4944 - val_accuracy: 0.7668
# Epoch 2/100
# 453/453 [==============================] - 67s 149ms/step - loss: 0.4992 - accuracy: 0.7703 - val_loss: 0.4576 - val_accuracy: 0.7896
# Epoch 3/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.4771 - accuracy: 0.7796 - val_loss: 0.4487 - val_accuracy: 0.7964
# Epoch 4/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4652 - accuracy: 0.7847 - val_loss: 0.4299 - val_accuracy: 0.8033
# Epoch 5/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.4482 - accuracy: 0.7947 - val_loss: 0.4260 - val_accuracy: 0.8052
# Epoch 6/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.4373 - accuracy: 0.7988 - val_loss: 0.4193 - val_accuracy: 0.8107
# Epoch 7/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.4288 - accuracy: 0.8016 - val_loss: 0.4059 - val_accuracy: 0.8100
# Epoch 8/100
# 453/453 [==============================] - 56s 125ms/step - loss: 0.4180 - accuracy: 0.8075 - val_loss: 0.4101 - val_accuracy: 0.8106
# Epoch 9/100
# 453/453 [==============================] - 58s 127ms/step - loss: 0.4110 - accuracy: 0.8122 - val_loss: 0.4143 - val_accuracy: 0.8035
# 453/453 [==============================] - 51s 112ms/step - loss: 0.2816 - accuracy: 0.8767 - val_loss: 0.3491 - val_accuracy: 0.8356
# Epoch 49/100
# 453/453 [==============================] - 44s 96ms/step - loss: 0.2898 - accuracy: 0.8714 - val_loss: 0.3564 - val_accuracy: 0.8339
# Epoch 50/100
# 453/453 [==============================] - 43s 96ms/step - loss: 0.2898 - accuracy: 0.8725 - val_loss: 0.3509 - val_accuracy: 0.8337
# Epoch 51/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.2809 - accuracy: 0.8764 - val_loss: 0.3242 - val_accuracy: 0.8548
# Epoch 52/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.2782 - accuracy: 0.8763 - val_loss: 0.3205 - val_accuracy: 0.8490
# Epoch 53/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.2693 - accuracy: 0.8828 - val_loss: 0.3498 - val_accuracy: 0.8646
# Test Loss: 0.3130
# Test Accuracy: 0.8583
# 283/283 [==============================] - 10s 31ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87      4524
#            1       0.90      0.80      0.85      4523
#
#     accuracy                           0.86      9047
#    macro avg       0.86      0.86      0.86      9047
# weighted avg       0.86      0.86      0.86      9047
#
#
# Confusion Matrix:
# [[4135  389]
#  [ 893 3630]]

# %%
# Build RNN model
def build_rnn3_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn3_model = build_rnn3_model(input_shape)

# Compile the model
rnn3_model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn3_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn3_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn3_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn3_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 400, 128)          72704
#
#  dropout_16 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_8 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  lstm_10 (LSTM)              (None, 400, 64)           49408
#
#  dropout_17 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_9 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  lstm_11 (LSTM)              (None, 32)                12416
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params:
# Epoch 19/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.3987 - accuracy: 0.8245 - val_loss: 0.5071 - val_accuracy: 0.7466
# Epoch 20/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.5286 - accuracy: 0.7391 - val_loss: 0.6991 - val_accuracy: 0.6779
# Epoch 21/100
# 453/453 [==============================] - 49s 109ms/step - loss: 0.4874 - accuracy: 0.7857 - val_loss: 0.6795 - val_accuracy: 0.6871
# Epoch 22/100
# 453/453 [==============================] - 60s 132ms/step - loss: 0.4724 - accuracy: 0.7882 - val_loss: 0.5390 - val_accuracy: 0.7769
# Epoch 23/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.5252 - accuracy: 0.7523 - val_loss: 0.6100 - val_accuracy: 0.6746
# Epoch 24/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.5597 - accuracy: 0.7301 - val_loss: 0.5833 - val_accuracy: 0.6716
# Epoch 25/100
# 453/453 [==============================] - 61s 134ms/step - loss: 0.5291 - accuracy: 0.7471 - val_loss: 0.5630 - val_accuracy: 0.7143
# Epoch 26/100
# 453/453 [==============================] - 53s 117ms/step - loss: 0.5210 - accuracy: 0.7493 - val_loss: 0.5353 - val_accuracy: 0.7282
# Epoch 27/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.5118 - accuracy: 0.7597 - val_loss: 0.5624 - val_accuracy: 0.7516
# Test Loss: 0.3915
# Test Accuracy: 0.8160
# 283/283 [==============================] - 11s 35ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      4524
#            1       0.83      0.79      0.81      4523
#
#     accuracy                           0.82      9047
#    macro avg       0.82      0.82      0.82      9047
# weighted avg       0.82      0.82      0.82      9047
#
#
# Confusion Matrix:
# [[3803  721]
#  [ 944 3579]]

# %%
# Build RNN model
def build_rnn10_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn10_model = build_rnn10_model(input_shape)

# Compile the model
rnn10_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn10_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn10_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn10_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn10_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 400, 128)          72704
#
#  dropout_20 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_10 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_13 (LSTM)              (None, 400, 64)           49408
#
#  dropout_21 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_11 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_14 (LSTM)              (None, 32)                12416
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dropout_23 (Dropout)        (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 62s 121ms/step - loss: 0.5329 - accuracy: 0.7473 - val_loss: 0.5577 - val_accuracy: 0.7053
# Epoch 2/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.4921 - accuracy: 0.7714 - val_loss: 0.4575 - val_accuracy: 0.7868
# Epoch 3/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4693 - accuracy: 0.7799 - val_loss: 0.4403 - val_accuracy: 0.7882
# Epoch 4/100
# 453/453 [==============================] - 54s 119ms/step - loss: 0.4544 - accuracy: 0.7844 - val_loss: 0.4389 - val_accuracy: 0.7919
# Epoch 5/100
# 453/453 [==============================] - 53s 118ms/step - loss: 0.4373 - accuracy: 0.7975 - val_loss: 0.4283 - val_accuracy: 0.7994
# Epoch 6/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4348 - accuracy: 0.7981 - val_loss: 0.4188 - val_accuracy: 0.8016
# Epoch 7/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4299 - accuracy: 0.7996 - val_loss: 0.4412 - val_accuracy: 0.7897
# Epoch 8/100
# 453/453 [==============================] - 62s 137ms/step - loss: 0.4206 - accuracy: 0.8018 - val_loss: 0.4123 - val_accuracy: 0.8037
# Epoch 9/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.4109 - accuracy: 0.8086 - val_loss: 0.3950 - val_accuracy: 0.8146
# Epoch 10/100
# 453/453 [==============================] - 54s 120ms/step - loss: 0.4007 - accuracy: 0.8131 - val_loss: 0.4179 - val_accuracy: 0.8052
# Epoch 11/100
# 453/453 [==============================] - 58s 128ms/step - loss: 0.3906 - accuracy: 0.8199 - val_loss: 0.4787 - val_accuracy: 0.8046
# Epoch 12/100
# 453/453 [==============================] - 58s 129ms/step - loss: 0.3832 - accuracy: 0.8221 - val_loss: 0.3817 - val_accuracy: 0.8196
# Epoch 13/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.3701 - accuracy: 0.8295 - val_loss: 0.4115 - val_accuracy: 0.8120
# Epoch 14/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.3648 - accuracy: 0.8345 - val_loss: 0.3734 - val_accuracy: 0.8294
# Epoch 15/100
# 453/453 [==============================] - 74s 164ms/step - loss: 0.0414 - accuracy: 0.9878 - val_loss: 0.1365 - val_accuracy: 0.9632
# Epoch 93/100
# 453/453 [==============================] - 73s 161ms/step - loss: 0.0364 - accuracy: 0.9881 - val_loss: 0.1459 - val_accuracy: 0.9588
# Epoch 94/100
# 453/453 [==============================] - 73s 161ms/step - loss: 0.0378 - accuracy: 0.9883 - val_loss: 0.1161 - val_accuracy: 0.9684
# Epoch 95/100
# 453/453 [==============================] - 74s 164ms/step - loss: 0.0359 - accuracy: 0.9884 - val_loss: 0.1612 - val_accuracy: 0.9557
# Epoch 96/100
# 453/453 [==============================] - 73s 160ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.1178 - val_accuracy: 0.9691
# Epoch 97/100
# 453/453 [==============================] - 73s 161ms/step - loss: 0.0653 - accuracy: 0.9796 - val_loss: 0.1217 - val_accuracy: 0.9624
# Epoch 98/100
# 453/453 [==============================] - 73s 161ms/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.1397 - val_accuracy: 0.9627
# Epoch 99/100
# 453/453 [==============================] - 74s 164ms/step - loss: 0.0360 - accuracy: 0.9884 - val_loss: 0.1136 - val_accuracy: 0.9697
# Epoch 100/100
# 453/453 [==============================] - 72s 159ms/step - loss: 0.0408 - accuracy: 0.9871 - val_loss: 0.1302 - val_accuracy: 0.9610
# Test Loss: 0.1303
# Test Accuracy: 0.9581
# 283/283 [==============================] - 18s 55ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4524
#            1       0.95      0.96      0.96      4523
#
#     accuracy                           0.96      9047
#    macro avg       0.96      0.96      0.96      9047
# weighted avg       0.96      0.96      0.96      9047
#
#
# Confusion Matrix:
# [[4319  205]
#  [ 174 4349]]

# %%
# Build RNN model
def build_rnn4_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.5),
        Dense(32, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn4_model = build_rnn4_model(input_shape)

# Compile the model
rnn4_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn4_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn4_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn4_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn4_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 400, 128)          72704
#
#  dropout_24 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_12 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_16 (LSTM)              (None, 400, 64)           49408
#
#  dropout_25 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_13 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_17 (LSTM)              (None, 32)                12416
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 80s 153ms/step - loss: 0.5587 - accuracy: 0.7308 - val_loss: 0.5115 - val_accuracy: 0.7561
# Epoch 2/100
# 453/453 [==============================] - 70s 155ms/step - loss: 0.5154 - accuracy: 0.7608 - val_loss: 0.4840 - val_accuracy: 0.7748
# Epoch 3/100
# 453/453 [==============================] - 85s 187ms/step - loss: 0.4963 - accuracy: 0.7706 - val_loss: 0.4765 - val_accuracy: 0.7921
# Epoch 4/100
# 453/453 [==============================] - 79s 175ms/step - loss: 0.4783 - accuracy: 0.7799 - val_loss: 0.4518 - val_accuracy: 0.7915
# Epoch 5/100
# 453/453 [==============================] - 95s 211ms/step - loss: 0.4735 - accuracy: 0.7843 - val_loss: 0.4316 - val_accuracy: 0.8059
# Epoch 6/100
# 453/453 [==============================] - 97s 215ms/step - loss: 0.4561 - accuracy: 0.7875 - val_loss: 0.4441 - val_accuracy: 0.7842
# Epoch 7/100
# 453/453 [==============================] - 64s 141ms/step - loss: 0.4433 - accuracy: 0.7949 - val_loss: 0.4732 - val_accuracy: 0.7501
# Epoch 8/100
# 453/453 [==============================] - 60s 133ms/step - loss: 0.4341 - accuracy: 0.7992 - val_loss: 0.4534 - val_accuracy: 0.7875
# Epoch 9/100
# 453/453 [==============================] - 69s 153ms/step - loss: 0.4247 - accuracy: 0.8048 - val_loss: 0.4131 - val_accuracy: 0.8006
# Epoch 10/100
# 453/453 [==============================] - 64s 142ms/step - loss: 0.4130 - accuracy: 0.8095 - val_loss: 0.4036 - val_accuracy: 0.8037
# Epoch 11/100
# 453/453 [==============================] - 65s 144ms/step - loss: 0.3991 - accuracy: 0.8153 - val_loss: 0.3876 - val_accuracy: 0.8153
# Epoch 12/100
# 453/453 [==============================] - 71s 156ms/step - loss: 0.3908 - accuracy: 0.8242 - val_loss: 0.3662 - val_accuracy: 0.8323
# Epoch 13/100
# 453/453 [==============================] - 64s 141ms/step - loss: 0.3856 - accuracy: 0.8259 - val_loss: 0.3797 - val_accuracy: 0.8187
# Epoch 14/100
# 453/453 [==============================] - 69s 152ms/step - loss: 0.3762 - accuracy: 0.8299 - val_loss: 0.3883 - val_accuracy: 0.8156
# Epoch 15/100
# 453/453 [==============================] - 69s 153ms/step - loss: 0.3686 - accuracy: 0.8320 - val_loss: 0.3893 - val_accuracy: 0.8191
# Epoch 16/100
step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4524
#            1       0.97      0.96      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4411  113]
#  [ 178 4345]]

# %%
# Build RNN model
def build_rnn5_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.7),
        Dense(32, activation='relu'),
        Dropout(0.7),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn5_model = build_rnn5_model(input_shape)

# Compile the model
rnn5_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn5_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn5_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn5_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn5_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 400, 128)          72704
#
#  dropout_28 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_14 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_19 (LSTM)              (None, 400, 64)           49408
#
#  dropout_29 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_15 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_20 (LSTM)              (None, 32)                12416
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 63s 123ms/step - loss: 0.6127 - accuracy: 0.6828 - val_loss: 0.5674 - val_accuracy: 0.7014
# Epoch 2/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.5543 - accuracy: 0.7423 - val_loss: 0.4947 - val_accuracy: 0.7733
# Epoch 3/100
# 453/453 [==============================] - 56s 123ms/step - loss: 0.5307 - accuracy: 0.7619 - val_loss: 0.4855 - val_accuracy: 0.7760
# Epoch 4/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.5135 - accuracy: 0.7676 - val_loss: 0.4728 - val_accuracy: 0.7839
# Epoch 5/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.5019 - accuracy: 0.7757 - val_loss: 0.4530 - val_accuracy: 0.7899
# Epoch 6/100
# Epoch 45/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.1694 - accuracy: 0.9385 - val_loss: 0.2625 - val_accuracy: 0.9018
# Epoch 46/100
# 453/453 [==============================] - 56s 125ms/step - loss: 0.1607 - accuracy: 0.9444 - val_loss: 0.2595 - val_accuracy: 0.9030
# Epoch 47/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.1550 - accuracy: 0.9464 - val_loss: 0.2620 - val_accuracy: 0.9124
# Test Loss: 0.2338
# Test Accuracy: 0.9038
# 283/283 [==============================] - 14s 44ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      4524
#            1       0.96      0.85      0.90      4523
#
#     accuracy                           0.90      9047
#    macro avg       0.91      0.90      0.90      9047
# weighted avg       0.91      0.90      0.90      9047
#
#
# Confusion Matrix:
# [[4346  178]
#  [ 692 3831]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn6_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn6_model = build_rnn6_model(input_shape)

# Compile the model with RMSprop optimizer
rnn6_model.compile(optimizer=RMSprop(learning_rate=0.001), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn6_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn6_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn6_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn6_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 400, 128)          72704
#
#  dropout_24 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_12 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_16 (LSTM)              (None, 400, 64)           49408
#
#  dropout_25 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_13 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_17 (LSTM)              (None, 32)                12416
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params:
# 453/453 [==============================] - 57s 126ms/step - loss: 0.0764 - accuracy: 0.9742 - val_loss: 0.1896 - val_accuracy: 0.9392
# Epoch 60/100
# 453/453 [==============================] - 61s 135ms/step - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.1922 - val_accuracy: 0.9449
# Epoch 61/100
# 453/453 [==============================] - 60s 134ms/step - loss: 0.0671 - accuracy: 0.9783 - val_loss: 0.1944 - val_accuracy: 0.9434
# Epoch 62/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.0689 - accuracy: 0.9772 - val_loss: 0.1472 - val_accuracy: 0.9525
# Epoch 63/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.0628 - accuracy: 0.9815 - val_loss: 0.1573 - val_accuracy: 0.9511
# Epoch 64/100
# 453/453 [==============================] - 61s 135ms/step - loss: 0.0614 - accuracy: 0.9815 - val_loss: 0.1867 - val_accuracy: 0.9445
# Epoch 65/100
# 453/453 [==============================] - 62s 136ms/step - loss: 0.0581 - accuracy: 0.9825 - val_loss: 0.1816 - val_accuracy: 0.9533
# Epoch 66/100
# 453/453 [==============================] - 58s 129ms/step - loss: 0.0581 - accuracy: 0.9827 - val_loss: 0.2111 - val_accuracy: 0.9432
# Test Loss: 0.1400
# Test Accuracy: 0.9542
# 283/283 [==============================] - 14s 45ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      4524
#            1       0.98      0.93      0.95      4523
#
#     accuracy                           0.95      9047
#    macro avg       0.96      0.95      0.95      9047
# weighted avg       0.96      0.95      0.95      9047
#
#
# Confusion Matrix:
# [[4420  104]
#  [ 310 4213]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn7_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn7_model = build_rnn7_model(input_shape)

# Compile the model with RMSprop optimizer
rnn7_model.compile(optimizer=RMSprop(learning_rate=0.0001), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn7_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn7_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn7_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn7_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 400, 128)          72704
#
#  dropout_28 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_14 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_19 (LSTM)              (None, 400, 64)           49408
#
#  dropout_29 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_15 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_20 (LSTM)              (None, 32)                12416
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 70s 137ms/step - loss: 0.5681 - accuracy: 0.7216 - val_loss: 0.4970 - val_accuracy: 0.7716
# Epoch 2/100
# 453/453 [==============================] - 55s 122ms/step - loss: 0.5155 - accuracy: 0.7616 - val_loss: 0.4805 - val_accuracy: 0.7745
# Epoch 3/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.4972 - accuracy: 0.7707 - val_loss: 0.4600 - val_accuracy: 0.7915
# Epoch 4/100
# 453/453 [==============================] - 61s 135ms/step - loss: 0.4837 - accuracy: 0.7793 - val_loss: 0.4572 - val_accuracy: 0.7882
# Epoch 5/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.4694 - accuracy: 0.7843 - val_loss: 0.4492 - val_accuracy: 0.7926
# Epoch 6/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.4579 - accuracy: 0.7907 - val_loss: 0.4458 - val_accuracy: 0.7932
# Epoch 7/100
# 453/453 [==============================] - 61s 135ms/step - loss: 0.4523 - accuracy: 0.7927 - val_loss: 0.4403 - val_accuracy: 0.7910
# Epoch 8/100
# 453/453 [==============================] - 57s 127ms/step - loss: 0.4409 - accuracy: 0.7953 - val_loss: 0.4630 - val_accuracy: 0.7836
# Epoch 9/100
# 453/453 [==============================] - 56s 123ms/step - loss: 0.4320 - accuracy: 0.8017 - val_loss: 0.4218 - val_accuracy: 0.8041
# Epoch 10/100
# 453/453 [==============================] - 60s 134ms/step - loss: 0.4278 - accuracy: 0.8046 - val_loss: 0.4468 - val_accuracy: 0.7947
# Epoch 11/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.4212 - accuracy: 0.8072 - val_loss: 0.4128 - val_accuracy: 0.8127
# Epoch 12/100
# 453/453 [==============================] - 55s 123ms/step - loss: 0.4145 - accuracy: 0.8082 - val_loss: 0.3966 - val_accuracy: 0.8180
# Epoch 13/100
# 453/453 [==============================] - 61s 134ms/step - loss: 0.4075 - accuracy: 0.8107 - val_loss: 0.3955 - val_accuracy: 0.8150
# Epoch 14/100
# 453/453 [==============================] - 58s 127ms/step - loss: 0.4040 - accuracy: 0.8122 - val_loss: 0.4092 - val_accuracy: 0.8118
# Epoch 15/100
# 453/453 [==============================] - 55s 122ms/step - loss: 0.3950 - accuracy: 0.8182 - val_loss: 0.3967 - val_accuracy: 0.8218
step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.89      4524
#            1       0.91      0.84      0.88      4523
#
#     accuracy                           0.88      9047
#    macro avg       0.88      0.88      0.88      9047
# weighted avg       0.88      0.88      0.88      9047
#
#
# Confusion Matrix:
# [[4164  360]
#  [ 708 3815]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn8_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn8_model = build_rnn8_model(input_shape)

# Compile the model with RMSprop optimizer
rnn8_model.compile(optimizer=RMSprop(learning_rate=0.01), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn8_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn8_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn8_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn8_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 400, 128)          72704
#
#  dropout_32 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_16 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_22 (LSTM)              (None, 400, 64)           49408
#
#  dropout_33 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_17 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_23 (LSTM)              (None, 32)                12416
#
#  dropout_34 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dropout_35 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 62s 124ms/step - loss: 0.6061 - accuracy: 0.6915 - val_loss: 0.6048 - val_accuracy: 0.6989
# Epoch 2/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.5569 - accuracy: 0.7394 - val_loss: 0.6109 - val_accuracy: 0.7578
# Epoch 3/100
# 453/453 [==============================] - 55s 122ms/step - loss: 0.5364 - accuracy: 0.7485 - val_loss: 0.5134 - val_accuracy: 0.7557
# Epoch 4/100
# 453/453 [==============================] - 56s 123ms/step - loss: 0.5134 - accuracy: 0.7615 - val_loss: 0.4790 - val_accuracy: 0.7810
# Epoch 5/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.4871 - accuracy: 0.7809 - val_loss: 0.4468 - val_accuracy: 0.8028
# Epoch 6/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.4745 - accuracy: 0.7925 - val_loss: 0.4783 - val_accuracy: 0.7908
# Epoch 7/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.4577 - accuracy: 0.7981 - val_loss: 0.4398 - val_accuracy: 0.8055
# Epoch 8/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.4419 - accuracy: 0.8085 - val_loss: 0.5936 - val_accuracy: 0.7477
# Epoch 9/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.4161 - accuracy: 0.8195 - val_loss: 0.4057 - val_accuracy: 0.8086
# Epoch 10/100
# 453/453 [==============================] - 57s 125ms/step - loss: 0.4148 - accuracy: 0.8202 - val_loss: 0.4377 - val_accuracy: 0.7998
# Epoch 11/100
# 453/453 [==============================] - 56s 123ms/step - loss: 0.4204 - accuracy: 0.8151 - val_loss: 0.4008 - val_accuracy: 0.8208
# Epoch 12/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.4212 - accuracy: 0.8179 - val_loss: 0.4225 - val_accuracy: 0.8183
# Epoch 13/100
# 453/453 [==============================] - 56s 123ms/step - loss: 0.4354 - accuracy: 0.8076 - val_loss: 0.4411 - val_accuracy: 0.8040
# Epoch 14/100
# 453/453 [==============================] - 61s 134ms/step - loss: 0.4294 - accuracy: 0.8114 - val_loss: 0.4245 - val_accuracy: 0.8066
# Epoch 15/100
# 453/453 [==============================] - 64s 140ms/step - loss: 0.4772 - accuracy: 0.7855 - val_loss: 0.5718 - val_accuracy: 0.7182
# Epoch 16/100
# 453/453 [==============================] - 59s 130ms/step - loss: 0.4919 - accuracy: 0.7788 - val_loss: 0.4955 - val_accuracy: 0.7868
# Epoch 17/100
# 453/453 [==============================] - 60s 133ms/step - loss: 0.4659 - accuracy: 0.7907 - val_loss: 0.5105 - val_accuracy: 0.7892
# Epoch 18/100
# 453/453 [==============================] - 65s 144ms/step - loss: 0.4654 - accuracy: 0.7946 - val_loss: 0.5364 - val_accuracy: 0.7662
# Epoch 19/100
# 453/453 [==============================] - 60s 132ms/step - loss: 0.4699 - accuracy: 0.7896 - val_loss: 0.5049 - val_accuracy: 0.7479
# Epoch 20/100
# 453/453 [==============================] - 62s 136ms/step - loss: 0.4773 - accuracy: 0.7853 - val_loss: 0.5018 - val_accuracy: 0.7626
# Epoch 21/100
# 453/453 [==============================] - 65s 144ms/step - loss: 0.4879 - accuracy: 0.7764 - val_loss: 0.6777 - val_accuracy: 0.5077
# Test Loss: 0.4013
# Test Accuracy: 0.8212
# 283/283 [==============================] - 14s 43ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83      4524
#            1       0.86      0.76      0.81      4523
#
#     accuracy                           0.82      9047
#    macro avg       0.83      0.82      0.82      9047
# weighted avg       0.83      0.82      0.82      9047
#
#
# Confusion Matrix:
# [[3974  550]
#  [1068 3455]]

# %%
# Save the trained model to a file
model_save_path = "rnn4(LTSM)_model.h5"  # You can change the file name/path
rnn4_model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to rnn4(LTSM)_model.h5
