# %%
import glob
import os
import librosa
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# Path to the metadata file
metadata_file_path = r'D:\download\Compressed\DF-keys-full\keys\DF\CM\trial_metadata.txt'

# Dictionary to hold file identifiers and labels
labels = {}
with open(metadata_file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        file_identifier = parts[1]
        label = parts[5]
        labels[file_identifier] = label

# Directory containing the undersampled audio files
undersampled_audio_dir = r'D:\audio_files\undersampled_audio'
audio_files = glob.glob(os.path.join(undersampled_audio_dir, '*.flac'))

valid_audio_files = []
valid_labels = []

for audio_file in audio_files:
    file_name = os.path.basename(audio_file)
    file_identifier = file_name.split('.')[0]
    if file_identifier in labels:
        valid_audio_files.append(audio_file)
        valid_labels.append(labels[file_identifier])

print(f"Found {len(valid_audio_files)} audio files with corresponding labels.")

# Audio to MFCC conversion function
def audio_to_mfcc(audio_file, sr=22050, n_mfcc=13):
    audio, sample_rate = librosa.load(audio_file, sr=sr)
    mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    return mfcc

def pad_or_truncate(mfcc, max_time_steps=400):
    if mfcc.shape[1] > max_time_steps:
        return mfcc[:, :max_time_steps]
    elif mfcc.shape[1] < max_time_steps:
        padding = max_time_steps - mfcc.shape[1]
        return np.pad(mfcc, ((0, 0), (0, padding)), mode='constant')
    return mfcc

# Preprocessing function with normalization
def preprocess_audio_files_rnn(audio_files, labels, n_mfcc=13, max_time_steps=400):
    mfcc_data = []
    label_data = []
    scaler = StandardScaler()
    
    for audio_file, label in zip(audio_files, labels):
        mfcc = audio_to_mfcc(audio_file, n_mfcc=n_mfcc)
        mfcc = pad_or_truncate(mfcc, max_time_steps=max_time_steps).T
        mfcc = scaler.fit_transform(mfcc)
        mfcc_data.append(mfcc)
        label_data.append(1 if label == 'spoof' else 0)

    return np.array(mfcc_data), np.array(label_data)

X, y = preprocess_audio_files_rnn(valid_audio_files, valid_labels)
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

def stratified_split_70_30(X, y, test_size=0.2, random_state=42):
    strat_split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    for train_idx, test_idx in strat_split.split(X, y):
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = stratified_split_70_30(X, y)
print(f"Training set distribution: {np.bincount(y_train)}")
print(f"Test set distribution: {np.bincount(y_test)}")

def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)
rnn_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Found 45234 audio files with corresponding labels.
# Shape of X: (45234, 400, 13)
# Shape of y: (45234,)
# Training set distribution: [18093 18094]
# Test set distribution: [4524 4523]
# Epoch 1/50
# 453/453 [==============================] - 47s 84ms/step - loss: 0.5666 - accuracy: 0.7213 - val_loss: 0.4953 - val_accuracy: 0.7727
# Epoch 2/50
# 453/453 [==============================] - 41s 91ms/step - loss: 0.5125 - accuracy: 0.7610 - val_loss: 0.4803 - val_accuracy: 0.7749
# Epoch 3/50
# 453/453 [==============================] - 41s 91ms/step - loss: 0.4876 - accuracy: 0.7761 - val_loss: 0.4490 - val_accuracy: 0.7900
# Epoch 4/50
# 453/453 [==============================] - 42s 93ms/step - loss: 0.4711 - accuracy: 0.7831 - val_loss: 0.4479 - val_accuracy: 0.7899
# Epoch 5/50
# 453/453 [==============================] - 45s 98ms/step - loss: 0.4575 - accuracy: 0.7893 - val_loss: 0.4299 - val_accuracy: 0.8022
# Epoch 6/50
# 453/453 [==============================] - 50s 110ms/step - loss: 0.4472 - accuracy: 0.7921 - val_loss: 0.4216 - val_accuracy: 0.8062
# Epoch 7/50
# 453/453 [==============================] - 47s 105ms/step - loss: 0.4355 - accuracy: 0.7979 - val_loss: 0.4234 - val_accuracy: 0.8028
# Epoch 8/50
# 453/453 [==============================] - 46s 102ms/step - loss: 0.4266 - accuracy: 0.8002 - val_loss: 0.4139 - val_accuracy: 0.8089
# Epoch 9/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.4181 - accuracy: 0.8039 - val_loss: 0.3992 - val_accuracy: 0.8153
# Epoch 10/50
# 453/453 [==============================] - 52s 114ms/step - loss: 0.4087 - accuracy: 0.8105 - val_loss: 0.3942 - val_accuracy: 0.8201
# Epoch 11/50
# 453/453 [==============================] - 48s 105ms/step - loss: 0.4003 - accuracy: 0.8127 - val_loss: 0.4001 - val_accuracy: 0.8175
# Epoch 12/50
# 453/453 [==============================] - 48s 105ms/step - loss: 0.3964 - accuracy: 0.8163 - val_loss: 0.3927 - val_accuracy: 0.8204
# Epoch 13/50
# 453/453 [==============================] - 50s 111ms/step - loss: 0.3881 - accuracy: 0.8170 - val_loss: 0.4020 - val_accuracy: 0.8221
# Epoch 14/50
# 453/453 [==============================] - 52s 115ms/step - loss: 0.3832 - accuracy: 0.8199 - val_loss: 0.3958 - val_accuracy: 0.8153
# Epoch 15/50
# 453/453 [==============================] - 48s 105ms/step - loss: 0.3832 - accuracy: 0.8210 - val_loss: 0.3713 - val_accuracy: 0.8273
# Epoch 16/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3708 - accuracy: 0.8289 - val_loss: 0.3698 - val_accuracy: 0.8339
# Epoch 17/50
# 453/453 [==============================] - 52s 116ms/step - loss: 0.3680 - accuracy: 0.8275 - val_loss: 0.3722 - val_accuracy: 0.8295
# Epoch 18/50
# 453/453 [==============================] - 50s 110ms/step - loss: 0.3657 - accuracy: 0.8268 - val_loss: 0.3673 - val_accuracy: 0.8306
# Epoch 19/50
# 453/453 [==============================] - 47s 105ms/step - loss: 0.3598 - accuracy: 0.8309 - val_loss: 0.3660 - val_accuracy: 0.8303
# Epoch 20/50
# 453/453 [==============================] - 51s 112ms/step - loss: 0.3596 - accuracy: 0.8339 - val_loss: 0.3590 - val_accuracy: 0.8306
# Epoch 21/50
# 453/453 [==============================] - 53s 117ms/step - loss: 0.3606 - accuracy: 0.8334 - val_loss: 0.3714 - val_accuracy: 0.8243
# Epoch 22/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3504 - accuracy: 0.8356 - val_loss: 0.3718 - val_accuracy: 0.8285
# Epoch 23/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3422 - accuracy: 0.8411 - val_loss: 0.3770 - val_accuracy: 0.8287
# Epoch 24/50
# 453/453 [==============================] - 51s 113ms/step - loss: 0.3383 - accuracy: 0.8405 - val_loss: 0.3537 - val_accuracy: 0.8384
# Epoch 25/50
# 453/453 [==============================] - 52s 114ms/step - loss: 0.3331 - accuracy: 0.8441 - val_loss: 0.3534 - val_accuracy: 0.8338
# Epoch 26/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3337 - accuracy: 0.8447 - val_loss: 0.3428 - val_accuracy: 0.8419
# Epoch 27/50
# 453/453 [==============================] - 49s 109ms/step - loss: 0.3273 - accuracy: 0.8502 - val_loss: 0.3601 - val_accuracy: 0.8410
# Epoch 28/50
# 453/453 [==============================] - 54s 119ms/step - loss: 0.3302 - accuracy: 0.8491 - val_loss: 0.3421 - val_accuracy: 0.8448
# Epoch 29/50
# 453/453 [==============================] - 49s 108ms/step - loss: 0.3366 - accuracy: 0.8430 - val_loss: 0.3524 - val_accuracy: 0.8390
# Epoch 30/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3262 - accuracy: 0.8490 - val_loss: 0.3353 - val_accuracy: 0.8457
# Epoch 31/50
# 453/453 [==============================] - 51s 113ms/step - loss: 0.3180 - accuracy: 0.8523 - val_loss: 0.3284 - val_accuracy: 0.8443
# Epoch 32/50
# 453/453 [==============================] - 53s 117ms/step - loss: 0.3207 - accuracy: 0.8516 - val_loss: 0.3425 - val_accuracy: 0.8431
# Epoch 33/50
# 453/453 [==============================] - 48s 106ms/step - loss: 0.3144 - accuracy: 0.8532 - val_loss: 0.3539 - val_accuracy: 0.8410
# Epoch 34/50
# 453/453 [==============================] - 49s 108ms/step - loss: 0.3279 - accuracy: 0.8510 - val_loss: 0.3573 - val_accuracy: 0.8436
# Epoch 35/50
# 453/453 [==============================] - 52s 116ms/step - loss: 0.3186 - accuracy: 0.8526 - val_loss: 0.3401 - val_accuracy: 0.8390
# Epoch 36/50
# 453/453 [==============================] - 51s 112ms/step - loss: 0.3217 - accuracy: 0.8522 - val_loss: 0.3518 - val_accuracy: 0.8343
# Test Loss: 0.3223
# Test Accuracy: 0.8508
# 283/283 [==============================] - 11s 34ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      4524
#            1       0.87      0.83      0.85      4523
#
#     accuracy                           0.85      9047
#    macro avg       0.85      0.85      0.85      9047
# weighted avg       0.85      0.85      0.85      9047
#
#
# Confusion Matrix:
# [[3959  565]
#  [ 785 3738]]

# %% [markdown]
# Here

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn2_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn2_model = build_rnn2_model(input_shape)

# Compile the model
rnn2_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn2_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn2_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn2_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn2_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 400, 128)          54912
#
#  dropout_4 (Dropout)         (None, 400, 128)          0
#
#  batch_normalization_2 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_1 (GRU)                 (None, 400, 64)           37248
#
#  dropout_5 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_3 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 57s 110ms/step - loss: 0.5962 - accuracy: 0.6877 - val_loss: 0.5268 - val_accuracy: 0.7542
# Epoch 2/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.5501 - accuracy: 0.7383 - val_loss: 0.5113 - val_accuracy: 0.7586
# Epoch 3/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.5386 - accuracy: 0.7457 - val_loss: 0.4986 - val_accuracy: 0.7649
# Epoch 4/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.5269 - accuracy: 0.7512 - val_loss: 0.4988 - val_accuracy: 0.7597
# Epoch 5/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.5174 - accuracy: 0.7573 - val_loss: 0.4792 - val_accuracy: 0.7765
# Epoch 6/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.5069 - accuracy: 0.7649 - val_loss: 0.4691 - val_accuracy: 0.7798
# Epoch 7/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.4975 - accuracy: 0.7679 - val_loss: 0.4722 - val_accuracy: 0.7792
# Epoch 8/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.4915 - accuracy: 0.7706 - val_loss: 0.4647 - val_accuracy: 0.7860
# Epoch 9/100
# 453/453 [==============================] - 48s 107ms/step - loss: 0.4831 - accuracy: 0.7775 - val_loss: 0.4524 - val_accuracy: 0.7871
# Epoch 10/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.4775 - accuracy: 0.7772 - val_loss: 0.4558 - val_accuracy: 0.7899
# Epoch 11/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4725 - accuracy: 0.7808 - val_loss: 0.4468 - val_accuracy: 0.7928
# Epoch 12/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4684 - accuracy: 0.7829 - val_loss: 0.4430 - val_accuracy: 0.7893
# Epoch 13/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.4619 - accuracy: 0.7836 - val_loss: 0.4515 - val_accuracy: 0.7919
# Epoch 14/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.4572 - accuracy: 0.7880 - val_loss: 0.4453 - val_accuracy: 0.7958
# Epoch 15/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.4548 - accuracy: 0.7881 - val_loss: 0.4418 - val_accuracy: 0.7933
# Epoch 16/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4493 - accuracy: 0.7908 - val_loss: 0.4363 - val_accuracy: 0.7943
# Epoch 17/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.4462 - accuracy: 0.7929 - val_loss: 0.4309 - val_accuracy: 0.7986
# Epoch 18/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.4439 - accuracy: 0.7938 - val_loss: 0.4361 - val_accuracy: 0.8009
# Epoch 19/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0
100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.1144 - accuracy: 0.9587 - val_loss: 0.1962 - val_accuracy: 0.9301
# Epoch 100/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.1123 - accuracy: 0.9605 - val_loss: 0.1644 - val_accuracy: 0.9367
# Test Loss: 0.1751
# Test Accuracy: 0.9394
# 283/283 [==============================] - 10s 31ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      4524
#            1       0.97      0.91      0.94      4523
#
#     accuracy                           0.94      9047
#    macro avg       0.94      0.94      0.94      9047
# weighted avg       0.94      0.94      0.94      9047
#
#
# Confusion Matrix:
# [[4388  136]
#  [ 412 4111]]

# %%
# Build RNN model
def build_rnn3_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn3_model = build_rnn3_model(input_shape)

# Compile the model
rnn3_model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn3_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn3_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn3_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn3_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 400, 128)          54912
#
#  dropout_8 (Dropout)         (None, 400, 128)          0
#
#  batch_normalization_4 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_4 (GRU)                 (None, 400, 64)           37248
#
#  dropout_9 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_5 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_5 (GRU)                 (None, 32)                9408
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 56s 108ms/step - loss: 0.5545 - accuracy: 0.7364 - val_loss: 0.4771 - val_accuracy: 0.7810
# Epoch 2/100
# 453/453 [==============================] - 44s 97ms/step - loss: 0.4369 - accuracy: 0.8013 - val_loss: 0.4216 - val_accuracy: 0.8085
# Epoch 3/100
# 453/453 [==============================] - 44s 97ms/step - loss: 0.4145 - accuracy: 0.8175 - val_loss: 0.5938 - val_accuracy: 0.7313
# Epoch 4/100
# 453/453 [==============================] - 48s 107ms/step - loss: 0.4259 - accuracy: 0.8112 - val_loss: 0.4488 - val_accuracy: 0.7874
# Epoch 5/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4353 - accuracy: 0.8009 - val_loss: 0.6686 - val_accuracy: 0.6281
# Epoch 6/100
# 453/453 [==============================] - 44s 96ms/step - loss: nan - accuracy: 0.5239 - val_loss: nan - val_accuracy: 0.4952
# Epoch 7/100
# 453/453 [==============================] - 43s 96ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Epoch 8/100
# 453/453 [==============================] - 48s 106ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Epoch 9/100
# 453/453 [==============================] - 47s 105ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Epoch 10/100
# 453/453 [==============================] - 43s 95ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Epoch 11/100
# 453/453 [==============================] - 43s 95ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Epoch 12/100
# 453/453 [==============================] - 48s 106ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.4952
# Test Loss: 0.4124
# Test Accuracy: 0.8121
# 283/283 [==============================] - 10s 29ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82      4524
#            1       0.86      0.75      0.80      4523
#
#     accuracy                           0.81      9047
#    macro avg       0.82      0.81      0.81      9047
# weighted avg       0.82      0.81      0.81      9047
#
#
# Confusion Matrix:
# [[3967  557]
#  [1143 3380]]

# %%
# Build RNN model
def build_rnn4_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.5),
        Dense(32, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn4_model = build_rnn4_model(input_shape)

# Compile the model
rnn4_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn4_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn4_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn4_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn4_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 400, 128)          54912
#
#  dropout_12 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_6 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_7 (GRU)                 (None, 400, 64)           37248
#
#  dropout_13 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_7 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_8 (GRU)                 (None, 32)                9408
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 50s 95ms/step - loss: 0.5874 - accuracy: 0.7108 - val_loss: 0.5230 - val_accuracy: 0.7498
# Epoch 2/100
# 453/453 [==============================] - 43s 94ms/step - loss: 0.5386 - accuracy: 0.7494 - val_loss: 0.5196 - val_accuracy: 0.7421
# Epoch 3/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.5154 - accuracy: 0.7608 - val_loss: 0.4807 - val_accuracy: 0.7759
# Epoch 4/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.4991 - accuracy: 0.7687 - val_loss: 0.4774 - val_accuracy: 0.7742
# Epoch 5/100
# 453/453 [==============================] - 44s 98ms/step - loss: 0.4781 - accuracy: 0.7772 - val_loss: 0.4367 - val_accuracy: 0.8017
# Epoch 6/100
# 453/453 [==============================] - 44s 97ms/step - loss: 0.4309 - accuracy: 0.8047 - val_loss: 0.4062 - val_accuracy: 0.8306
# Epoch 7/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.3757 - accuracy: 0.8378 - val_loss: 0.3097 - val_accuracy: 0.8627
# Epoch 8/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.3085 - accuracy: 0.8729 - val_loss: 0.2610 - val_accuracy: 0.8911
# Epoch 9/100
# 453/453 [==============================] - 44s 98ms/step - loss: 0.2456 - accuracy: 0.9062 - val_loss: 0.2167 - val_accuracy: 0.9199
# Epoch 10/100
# 453/453 [==============================] - 44s 97ms/step - loss: 0.1889 - accuracy: 0.9300 - val_loss: 0.2821 - val_accuracy: 0.8860
# Epoch 11/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0
100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.0217 - accuracy: 0.9940 - val_loss: 0.1202 - val_accuracy: 0.9755
# Epoch 33/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.0232 - accuracy: 0.9932 - val_loss: 0.1101 - val_accuracy: 0.9758
# Epoch 34/100
# 453/453 [==============================] - 49s 109ms/step - loss: 0.0185 - accuracy: 0.9950 - val_loss: 0.0933 - val_accuracy: 0.9808
# Epoch 35/100
# 453/453 [==============================] - 49s 109ms/step - loss: 0.0197 - accuracy: 0.9948 - val_loss: 0.1103 - val_accuracy: 0.9769
# Epoch 36/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.1638 - val_accuracy: 0.9684
# Epoch 37/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.1030 - val_accuracy: 0.9762
# Epoch 38/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.0148 - accuracy: 0.9960 - val_loss: 0.0934 - val_accuracy: 0.9811
# Epoch 39/100
# 453/453 [==============================] - 49s 107ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.1452 - val_accuracy: 0.9751
# Epoch 40/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.1206 - val_accuracy: 0.9746
# Epoch 41/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.2008 - val_accuracy: 0.9573
# Epoch 42/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.1202 - val_accuracy: 0.9811
# Epoch 43/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.1125 - val_accuracy: 0.9764
# Epoch 44/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.0131 - accuracy: 0.9969 - val_loss: 0.1245 - val_accuracy: 0.9685
# Test Loss: 0.1053
# Test Accuracy: 0.9805
# 283/283 [==============================] - 9s 27ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4524
#            1       0.99      0.97      0.98      4523
#
#     accuracy                           0.98      9047
#    macro avg       0.98      0.98      0.98      9047
# weighted avg       0.98      0.98      0.98      9047
#
#
# Confusion Matrix:
# [[4482   42]
#  [ 134 4389]]

# %%
# Build RNN model
def build_rnn5_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.7),
        Dense(32, activation='relu'),
        Dropout(0.7),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn5_model = build_rnn5_model(input_shape)

# Compile the model
rnn5_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn5_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn5_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn5_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn5_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_9 (GRU)                 (None, 400, 128)          54912
#
#  dropout_16 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_8 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_10 (GRU)                (None, 400, 64)           37248
#
#  dropout_17 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_9 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_11 (GRU)                (None, 32)                9408
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params:
# 453/453 [==============================] - 45s 98ms/step - loss: 0.0883 - accuracy: 0.9732 - val_loss: 0.2310 - val_accuracy: 0.9349
# Epoch 23/100
# 453/453 [==============================] - 44s 97ms/step - loss: 0.0745 - accuracy: 0.9789 - val_loss: 0.3486 - val_accuracy: 0.8972
# Epoch 24/100
# 453/453 [==============================] - 49s 107ms/step - loss: 0.0662 - accuracy: 0.9808 - val_loss: 0.1507 - val_accuracy: 0.9621
# Epoch 25/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.0532 - accuracy: 0.9848 - val_loss: 0.1689 - val_accuracy: 0.9603
# Epoch 26/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.0705 - accuracy: 0.9799 - val_loss: 0.1234 - val_accuracy: 0.9699
# Epoch 27/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 0.1457 - val_accuracy: 0.9623
# Epoch 28/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.0542 - accuracy: 0.9840 - val_loss: 0.2704 - val_accuracy: 0.9403
# Epoch 29/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.0676 - accuracy: 0.9795 - val_loss: 0.1592 - val_accuracy: 0.9634
# Epoch 30/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.0481 - accuracy: 0.9867 - val_loss: 0.1457 - val_accuracy: 0.9659
# Epoch 31/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.0437 - accuracy: 0.9877 - val_loss: 0.1961 - val_accuracy: 0.9557
# Epoch 32/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.0445 - accuracy: 0.9881 - val_loss: 0.4433 - val_accuracy: 0.9059
# Epoch 33/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.0407 - accuracy: 0.9892 - val_loss: 0.2009 - val_accuracy: 0.9476
# Epoch 34/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.0371 - accuracy: 0.9897 - val_loss: 0.2235 - val_accuracy: 0.9617
# Epoch 35/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 0.1431 - val_accuracy: 0.9710
# Epoch 36/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.0377 - accuracy: 0.9899 - val_loss: 0.1432 - val_accuracy: 0.9639
# Test Loss: 0.1185
# Test Accuracy: 0.9691
# 283/283 [==============================] - 9s 28ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      4524
#            1       0.97      0.97      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4391  133]
#  [ 147 4376]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn6_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn6_model = build_rnn6_model(input_shape)

# Compile the model with RMSprop optimizer
rnn6_model.compile(optimizer=RMSprop(learning_rate=0.001), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn6_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn6_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn6_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn6_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_12 (GRU)                (None, 400, 128)          54912
#
#  dropout_20 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_10 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  gru_13 (GRU)                (None, 400, 64)           37248
#
#  dropout_21 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_11 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  gru_14 (GRU)                (None, 32)                9408
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dropout_23 (Dropout)        (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 54s 105ms/step - loss: 0.5477 - accuracy: 0.7401 - val_loss: 0.5147 - val_accuracy: 0.7628
# Epoch 2/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.5031 - accuracy: 0.7628 - val_loss: 0.5012 - val_accuracy: 0.7666
# Epoch 3/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.4851 - accuracy: 0.7729 - val_loss: 0.4590 - val_accuracy: 0.7852
# Epoch 4/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.4744 - accuracy: 0.7769 - val_loss: 0.4554 - val_accuracy: 0.7886
# Epoch 5/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.4609 - accuracy: 0.7830 - val_loss: 0.4554 - val_accuracy: 0.7868
# Epoch 6/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.4367 - accuracy: 0.7930 - val_loss: 0.4035 - val_accuracy: 0.8128
# Epoch 7/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.4017 - accuracy: 0.8153 - val_loss: 0.4204 - val_accuracy: 0.8081
# Epoch 8/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.3586 - accuracy: 0.8383 - val_loss: 0.3382 - val_accuracy: 0.8453
# Epoch 9/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.3060 - accuracy: 0.8677 - val_loss: 0.3859 - val_accuracy: 0.8269
# Epoch 10/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.2532 - accuracy: 0.8961 - val_loss: 0.3498 - val_accuracy: 0.8566
# Epoch 11/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.2048 - accuracy: 0.9216 - val_loss: 0.2669 - val_accuracy: 0.9009
# Epoch 12/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.1621 - accuracy: 0.9397 - val_loss: 0.1803 - val_accuracy: 0.9283
# Epoch 13/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.1326 - accuracy: 0.9514 - val_loss: 0.1677 - val_accuracy: 0.9395
# Epoch 14/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.1115 - accuracy: 0.9622 - val_loss: 0.2772 - val_accuracy: 0.9135
# Epoch 15/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.0944 - accuracy: 0.9682 - val_loss: 0.1422 - val_accuracy: 0.9505
# Epoch 16/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.0787 - accuracy: 0.9733 - val_loss: 0.1225 - val_accuracy: 0.9605
# Epoch 17/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.0670 - accuracy: 0.9779 - val_loss: 0.1153 - val_accuracy: 0.9674
# Epoch 18/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.0582 - accuracy: 0.9814 - val_loss: 0.1837 - val_accuracy: 0.9533
# Epoch 19/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.0534 - accuracy: 0.9825 - val_loss: 0.1226 - val_accuracy: 0.9679
# Epoch 20/100
# 453/453 [==============================] - 49s 107ms/step - loss: 0.0451 - accuracy: 0.9860 - val_loss: 0.1695 - val_accuracy: 0.9664
100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.0872 - val_accuracy: 0.9833
# Epoch 43/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.2422 - val_accuracy: 0.9678
# Epoch 44/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.1526 - val_accuracy: 0.9783
# Epoch 45/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.1280 - val_accuracy: 0.9815
# Epoch 46/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.1125 - val_accuracy: 0.9815
# Epoch 47/100
# 453/453 [==============================] - 51s 114ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.1352 - val_accuracy: 0.9784
# Epoch 48/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.1270 - val_accuracy: 0.9790
# Epoch 49/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.1562 - val_accuracy: 0.9797
# Epoch 50/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.1369 - val_accuracy: 0.9807
# Epoch 51/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.1193 - val_accuracy: 0.9829
# Epoch 52/100
# 453/453 [==============================] - 49s 107ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.4425 - val_accuracy: 0.9591
# Test Loss: 0.1101
# Test Accuracy: 0.9804
# 283/283 [==============================] - 9s 27ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4524
#            1       0.99      0.97      0.98      4523
#
#     accuracy                           0.98      9047
#    macro avg       0.98      0.98      0.98      9047
# weighted avg       0.98      0.98      0.98      9047
#
#
# Confusion Matrix:
# [[4495   29]
#  [ 148 4375]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn7_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn7_model = build_rnn7_model(input_shape)

# Compile the model with RMSprop optimizer
rnn7_model.compile(optimizer=RMSprop(learning_rate=0.0001), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn7_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn7_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn7_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn7_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_15 (GRU)                (None, 400, 128)          54912
#
#  dropout_24 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_12 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  gru_16 (GRU)                (None, 400, 64)           37248
#
#  dropout_25 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_13 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  gru_17 (GRU)                (None, 32)                9408
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params:
100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.1414 - accuracy: 0.9470 - val_loss: 0.2087 - val_accuracy: 0.9196
# Epoch 91/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.1364 - accuracy: 0.9501 - val_loss: 0.1971 - val_accuracy: 0.9247
# Epoch 92/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.1346 - accuracy: 0.9507 - val_loss: 0.1829 - val_accuracy: 0.9294
# Epoch 93/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.1303 - accuracy: 0.9518 - val_loss: 0.2057 - val_accuracy: 0.9182
# Epoch 94/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.1293 - accuracy: 0.9531 - val_loss: 0.1755 - val_accuracy: 0.9312
# Epoch 95/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.1246 - accuracy: 0.9560 - val_loss: 0.2062 - val_accuracy: 0.9224
# Epoch 96/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.1237 - accuracy: 0.9553 - val_loss: 0.1902 - val_accuracy: 0.9283
# Epoch 97/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.1177 - accuracy: 0.9589 - val_loss: 0.1759 - val_accuracy: 0.9337
# Epoch 98/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.1167 - accuracy: 0.9602 - val_loss: 0.2074 - val_accuracy: 0.9181
# Epoch 99/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.1119 - accuracy: 0.9605 - val_loss: 0.1876 - val_accuracy: 0.9262
# Epoch 100/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.1103 - accuracy: 0.9616 - val_loss: 0.1663 - val_accuracy: 0.9344
# Test Loss: 0.1807
# Test Accuracy: 0.9318
# 283/283 [==============================] - 9s 27ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      4524
#            1       0.94      0.93      0.93      4523
#
#     accuracy                           0.93      9047
#    macro avg       0.93      0.93      0.93      9047
# weighted avg       0.93      0.93      0.93      9047
#
#
# Confusion Matrix:
# [[4240  284]
#  [ 333 4190]]

# %%
from tensorflow.keras.optimizers import RMSprop


# Build RNN model
def build_rnn8_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        LSTM(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn8_model = build_rnn8_model(input_shape)

# Compile the model with RMSprop optimizer
rnn8_model.compile(optimizer=RMSprop(learning_rate=0.01), 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# Add model summary
rnn8_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn8_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn8_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn8_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 400, 128)          72704
#
#  dropout_28 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_14 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  lstm_4 (LSTM)               (None, 400, 64)           49408
#
#  dropout_29 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_15 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 136,385
# Trainable params: 136,001
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 54s 104ms/step - loss: 0.6028 - accuracy: 0.6932 - val_loss: 0.5887 - val_accuracy: 0.7320
# Epoch 2/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.5565 - accuracy: 0.7376 - val_loss: 0.5637 - val_accuracy: 0.7477
# Epoch 3/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.5400 - accuracy: 0.7486 - val_loss: 0.9737 - val_accuracy: 0.7422
# Epoch 4/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.5209 - accuracy: 0.7620 - val_loss: 0.5202 - val_accuracy: 0.7472
# Epoch 5/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.4992 - accuracy: 0.7726 - val_loss: 0.5876 - val_accuracy: 0.6836
# Epoch 6/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.4708 - accuracy: 0.7897 - val_loss: 0.5357 - val_accuracy: 0.7056
# Epoch 7/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.4601 - accuracy: 0.7944 - val_loss: 0.4576 - val_accuracy: 0.8187
# Epoch 8/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.4255 - accuracy: 0.8115 - val_loss: 0.3794 - val_accuracy: 0.8309
# Epoch 9/100
# 453/453 [==============================] - 47s 105ms/step - loss: 0.4231 - accuracy: 0.8143 - val_loss: 0.4529 - val_accuracy: 0.7897
# Epoch 10/100
# 453/453 [==============================] - 48s 107ms/step - loss: 0.4280 - accuracy: 0.8099 - val_loss: 0.6794 - val_accuracy: 0.6873
# Epoch 11/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.4187 - accuracy: 0.8210 - val_loss: 0.5238 - val_accuracy: 0.7959
# Epoch 12/100
# 453/453 [==============================] - 49s 107ms/step - loss: 0.4242 - accuracy: 0.8181 - val_loss: 0.4281 - val_accuracy: 0.8091
# Epoch 13/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4443 - accuracy: 0.8065 - val_loss: 0.4821 - val_accuracy: 0.7903
# Epoch 14/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.4354 - accuracy: 0.8095 - val_loss: 0.4229 - val_accuracy: 0.8167
# Epoch 15/100
# 453/453 [==============================] - 54s 119ms/step - loss: 0.4203 - accuracy: 0.8227 - val_loss: 0.4134 - val_accuracy: 0.8367
# Epoch 16/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.4368 - accuracy: 0.8134 - val_loss: 0.4834 - val_accuracy: 0.7921
# Epoch 17/100
# 453/453 [==============================] - 48s 107ms/step - loss: 0.4382 - accuracy: 0.8124 - val_loss: 0.5227 - val_accuracy: 0.7716
# Epoch 18/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4471 - accuracy: 0.8034 - val_loss: 0.5667 - val_accuracy: 0.7248
# Test Loss: 0.3810
# Test Accuracy: 0.8340
# 283/283 [==============================] - 10s 31ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82      4524
#            1       0.80      0.89      0.84      4523
#
#     accuracy                           0.83      9047
#    macro avg       0.84      0.83      0.83      9047
# weighted avg       0.84      0.83      0.83      9047
#
#
# Confusion Matrix:
# [[3499 1025]
#  [ 477 4046]]

# %%
# Save the trained model to a file
model_save_path = "rnn6_model.keras"  # You can change the file name/path
rnn6_model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to rnn6_model.keras
