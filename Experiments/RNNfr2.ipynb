# %%
import glob
import os
import librosa
import numpy as np

# Path to the metadata file
metadata_file_path = r'D:\download\Compressed\DF-keys-full\keys\DF\CM\trial_metadata.txt'

# Dictionary to hold file identifiers and labels
labels = {}

# Open and read the metadata file
with open(metadata_file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        file_identifier = parts[1]  # Example: DF_E_2000011
        label = parts[5]            # Example: "spoof"
        labels[file_identifier] = label

# Directory containing the undersampled audio files
undersampled_audio_dir = r'D:\audio_files\undersampled_audio'

# Find all .flac files in the undersampled directory
audio_files = glob.glob(os.path.join(undersampled_audio_dir, '*.flac'))

# Create a list to store only those files that have corresponding labels in the metadata
valid_audio_files = []
valid_labels = []

# Loop through the audio files and match with metadata labels
for audio_file in audio_files:
    file_name = os.path.basename(audio_file)
    file_identifier = file_name.split('.')[0]  # Extract the file identifier (before the extension)

    # Check if the file identifier exists in the metadata labels
    if file_identifier in labels:
        valid_audio_files.append(audio_file)  # Keep this audio file
        valid_labels.append(labels[file_identifier])  # Store the corresponding label (spoof/bonafide)

# Print the number of matching files
print(f"Found {len(valid_audio_files)} audio files with corresponding labels.")

# Audio to MFCC conversion function
def audio_to_mfcc(audio_file, sr=22050, n_mfcc=13):
    """Convert audio to MFCC."""
    audio, sample_rate = librosa.load(audio_file, sr=sr)
    mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    return mfcc

# Function to pad or truncate MFCC to a fixed sequence length
def pad_or_truncate(mfcc, max_time_steps=400):
    """Ensure all MFCCs have the same time dimension by padding or truncating."""
    if mfcc.shape[1] > max_time_steps:  # Truncate if longer
        return mfcc[:, :max_time_steps]
    elif mfcc.shape[1] < max_time_steps:  # Pad with zeros if shorter
        padding = max_time_steps - mfcc.shape[1]
        return np.pad(mfcc, ((0, 0), (0, padding)), mode='constant')
    return mfcc

# Preprocessing the audio files for RNN input
def preprocess_audio_files_rnn(audio_files, labels, n_mfcc=13, max_time_steps=400):
    """Convert audio files to MFCCs, normalize, and prepare for RNN."""
    mfcc_data = []
    label_data = []

    for audio_file, label in zip(audio_files, labels):
        mfcc = audio_to_mfcc(audio_file, n_mfcc=n_mfcc)  # Extract MFCC
        mfcc = pad_or_truncate(mfcc, max_time_steps=max_time_steps)  # Pad/truncate
        mfcc = mfcc.T  # Transpose to shape (time_steps, n_mfcc)

        # Normalize
        max_value = np.max(mfcc)
        if max_value > 0:
            mfcc = mfcc / max_value

        mfcc_data.append(mfcc)
        label_data.append(1 if label == 'spoof' else 0)  # Binary label

    return np.array(mfcc_data), np.array(label_data)

# Preprocess the valid audio files and labels
X, y = preprocess_audio_files_rnn(valid_audio_files, valid_labels, n_mfcc=13, max_time_steps=400)

# RNN-ready data shape
print(f"Shape of X: {X.shape}")  # Should be (num_samples, max_time_steps, n_mfcc)
print(f"Shape of y: {y.shape}")  # Should be (num_samples,)
# Out:
# Found 45234 audio files with corresponding labels.
# Shape of X: (45234, 400, 13)
# Shape of y: (45234,)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np

# Stratified 80:20 train-test split
def stratified_split_70_30(X, y, test_size=0.2, random_state=42):
    """Split dataset into stratified 70/30 sets."""
    strat_split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    
    for train_idx, test_idx in strat_split.split(X, y):
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]
    
    # Ensure that the training set has balanced classes
    class_counts = np.bincount(y_train)
    min_class_count = min(class_counts)
    spoof_indices = np.where(y_train == 1)[0][:min_class_count]
    bonafide_indices = np.where(y_train == 0)[0][:min_class_count]
    balanced_train_indices = np.concatenate([spoof_indices, bonafide_indices])
    X_train_balanced, y_train_balanced = X_train[balanced_train_indices], y_train[balanced_train_indices]

    return X_train_balanced, X_test, y_train_balanced, y_test

# Perform the stratified 80:20 split
X_train, X_test, y_train, y_test = stratified_split_70_30(X, y, test_size=0.2, random_state=42)

# Print the distribution of classes to verify stratification
print(f"Training set distribution: {np.bincount(y_train)}")
print(f"Test set distribution: {np.bincount(y_test)}")
# Out:
# Training set distribution: [18093 18093]
# Test set distribution: [4524 4523]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)

# Compile the model
rnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 400, 128)          54912
#
#  dropout (Dropout)           (None, 400, 128)          0
#
#  batch_normalization (BatchN  (None, 400, 128)         512
#  ormalization)
#
#  gru_1 (GRU)                 (None, 400, 64)           37248
#
#  dropout_1 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_1 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 67s 121ms/step - loss: 0.6683 - accuracy: 0.6207 - val_loss: 0.9078 - val_accuracy: 2.7632e-04
# Epoch 2/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.6646 - accuracy: 0.6249 - val_loss: 0.9304 - val_accuracy: 2.7632e-04
# Epoch 3/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.6193 - accuracy: 0.6638 - val_loss: 0.1627 - val_accuracy: 1.0000
# Epoch 4/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4633 - accuracy: 0.8192 - val_loss: 0.6076 - val_accuracy: 0.6742
# Epoch 5/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.4129 - accuracy: 0.8305 - val_loss: 0.4461 - val_accuracy: 0.6966
# Epoch 6/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.3764 - accuracy: 0.8422 - val_loss: 0.5979 - val_accuracy: 0.7510
# Epoch 7/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.3509 - accuracy: 0.8487 - val_loss: 0.8073 - val_accuracy: 0.6601
# Epoch 8/100
# 453/453 [==============================] - 47s 104ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 0.0198 - val_accuracy: 0.9949
# Epoch 50/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.0221 - accuracy: 0.9924 - val_loss: 0.0159 - val_accuracy: 0.9959
# Epoch 51/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.0250 - accuracy: 0.9914 - val_loss: 0.2073 - val_accuracy: 0.9399
# Epoch 52/100
# 453/453 [==============================] - 48s 107ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.0381 - val_accuracy: 0.9878
# Epoch 53/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0152 - val_accuracy: 0.9953
# Epoch 54/100
# 453/453 [==============================] - 54s 120ms/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.0099 - val_accuracy: 0.9967
# Test Loss: 0.1320
# Test Accuracy: 0.9717
# 283/283 [==============================] - 11s 35ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4524
#            1       1.00      0.94      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4519    5]
#  [ 251 4272]]

# %%
# Build RNN model
def build_rnn2_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn2_model = build_rnn2_model(input_shape)

# Compile the model
rnn2_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn2_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn2_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn2_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 400, 128)          54912
#
#  dropout_4 (Dropout)         (None, 400, 128)          0
#
#  batch_normalization_2 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_4 (GRU)                 (None, 400, 64)           37248
#
#  dropout_5 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_3 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_5 (GRU)                 (None, 32)                9408
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 63s 122ms/step - loss: 0.6710 - accuracy: 0.6160 - val_loss: 0.7970 - val_accuracy: 2.7632e-04
# Epoch 2/100
# 453/453 [==============================] - 59s 130ms/step - loss: 0.6682 - accuracy: 0.6212 - val_loss: 0.8815 - val_accuracy: 2.7632e-04
# Epoch 3/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.6667 - accuracy: 0.6238 - val_loss: 0.8482 - val_accuracy: 2.7632e-04
# Epoch 4/100
# 453/453 [==============================] - 54s 119ms/step - loss: 0.6662 - accuracy: 0.6243 - val_loss: 0.8985 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.6653 - accuracy: 0.6245 - val_loss: 0.8556 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.6660 - accuracy: 0.6246 - val_loss: 0.8415 - val_accuracy: 2.7632e-04
# Epoch 7/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.6643 - accuracy: 0.6248 - val_loss: 0.9234 - val_accuracy: 2.7632e-04
# Epoch 8/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.6655 - accuracy: 0.6250 - val_loss: 0.9185 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.6648 - accuracy: 0.6247 - val_loss: 0.9054 - val_accuracy: 2.7632e-04
# Epoch 10/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.6645 - accuracy: 0.6249 - val_loss: 0.9074 - val_accuracy: 2.7632e-04
# Epoch 11/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.6644 - accuracy: 0.6250 - val_loss: 0.8945 - val_accuracy: 2.7632e-04
# Test Loss: 0.6980
# Test Accuracy: 0.4999
# 283/283 [==============================] - 8s 27ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4524
#            1       1.00      0.94      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4519    5]
#  [ 251 4272]]

# %%
# Build RNN model
def build_rnn3_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn3_model = build_rnn3_model(input_shape)

# Compile the model
rnn3_model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn3_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn3_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn3_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 400, 128)          54912
#
#  dropout_8 (Dropout)         (None, 400, 128)          0
#
#  batch_normalization_4 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_7 (GRU)                 (None, 400, 64)           37248
#
#  dropout_9 (Dropout)         (None, 400, 64)           0
#
#  batch_normalization_5 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_8 (GRU)                 (None, 32)                9408
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 54s 103ms/step - loss: 0.5434 - accuracy: 0.7362 - val_loss: 0.9908 - val_accuracy: 0.3168
# Epoch 2/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.4178 - accuracy: 0.8269 - val_loss: 0.6849 - val_accuracy: 0.6372
# Epoch 3/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.4021 - accuracy: 0.8314 - val_loss: 1.3773 - val_accuracy: 0.1250
# Epoch 4/100
# 453/453 [==============================] - 45s 98ms/step - loss: 0.3907 - accuracy: 0.8363 - val_loss: 0.6463 - val_accuracy: 0.5948
# Epoch 5/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.3851 - accuracy: 0.8343 - val_loss: 0.3711 - val_accuracy: 0.8244
# Epoch 6/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.3734 - accuracy: 0.8399 - val_loss: 0.9552 - val_accuracy: 0.5231
# Epoch 7/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.3694 - accuracy: 0.8413 - val_loss: 0.8577 - val_accuracy: 0.4255
# Epoch 8/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.3684 - accuracy: 0.8426 - val_loss: 0.7079 - val_accuracy: 0.6353
# Epoch 9/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0
# Epoch 34/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.3109 - accuracy: 0.8670 - val_loss: 0.3574 - val_accuracy: 0.8335
# Epoch 35/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.3134 - accuracy: 0.8678 - val_loss: 0.8516 - val_accuracy: 0.7661
# Epoch 36/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.3606 - accuracy: 0.8459 - val_loss: 0.5434 - val_accuracy: 0.8285
# Epoch 37/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.3543 - accuracy: 0.8516 - val_loss: 0.5471 - val_accuracy: 0.8031
# Epoch 38/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4842 - accuracy: 0.7554 - val_loss: 0.8568 - val_accuracy: 0.0137
# Epoch 39/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.6268 - accuracy: 0.6554 - val_loss: 0.8879 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.6199 - accuracy: 0.6559 - val_loss: 0.7616 - val_accuracy: 0.0573
# Epoch 41/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.5829 - accuracy: 0.6914 - val_loss: 0.6893 - val_accuracy: 0.7495
# Epoch 42/100
# 453/453 [==============================] - 44s 98ms/step - loss: 0.5233 - accuracy: 0.7591 - val_loss: 0.2138 - val_accuracy: 0.9138
# Epoch 43/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.4765 - accuracy: 0.7986 - val_loss: 0.6192 - val_accuracy: 0.8269
# Test Loss: 0.4447
# Test Accuracy: 0.8107
# 283/283 [==============================] - 9s 30ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4524
#            1       1.00      0.94      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4519    5]
#  [ 251 4272]]

# %%
# Build RNN model
def build_rnn4_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.5),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.5),
        Dense(32, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn4_model = build_rnn4_model(input_shape)

# Compile the model
rnn4_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn4_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn4_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn4_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_9 (GRU)                 (None, 400, 128)          54912
#
#  dropout_12 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_6 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_10 (GRU)                (None, 400, 64)           37248
#
#  dropout_13 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_7 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_11 (GRU)                (None, 32)                9408
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1
100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.2532 - accuracy: 0.8917 - val_loss: 0.2091 - val_accuracy: 0.8704
# Epoch 23/100
# 453/453 [==============================] - 46s 102ms/step - loss: 0.2438 - accuracy: 0.8979 - val_loss: 0.1900 - val_accuracy: 0.9178
# Epoch 24/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.2397 - accuracy: 0.8955 - val_loss: 0.0930 - val_accuracy: 0.9581
# Epoch 25/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.2361 - accuracy: 0.8951 - val_loss: 0.4013 - val_accuracy: 0.7700
# Epoch 26/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.4247 - accuracy: 0.8185 - val_loss: 0.5329 - val_accuracy: 0.6122
# Epoch 27/100
# 453/453 [==============================] - 49s 109ms/step - loss: 0.3839 - accuracy: 0.8337 - val_loss: 0.2712 - val_accuracy: 0.8116
# Epoch 28/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.3599 - accuracy: 0.8406 - val_loss: 0.6444 - val_accuracy: 0.6680
# Epoch 29/100
# 453/453 [==============================] - 47s 103ms/step - loss: 0.3494 - accuracy: 0.8478 - val_loss: 0.6699 - val_accuracy: 0.6756
# Epoch 30/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.3270 - accuracy: 0.8595 - val_loss: 0.8383 - val_accuracy: 0.6230
# Epoch 31/100
# 453/453 [==============================] - 50s 110ms/step - loss: 0.3080 - accuracy: 0.8685 - val_loss: 0.6785 - val_accuracy: 0.7147
# Test Loss: 0.5433
# Test Accuracy: 0.7727
# 283/283 [==============================] - 9s 31ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4524
#            1       1.00      0.94      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4519    5]
#  [ 251 4272]]

# %%
# Build RNN model
def build_rnn5_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.7),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.7),
        Dense(32, activation='relu'),
        Dropout(0.7),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn5_model = build_rnn5_model(input_shape)

# Compile the model
rnn5_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn5_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn5_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn5_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_12 (GRU)                (None, 400, 128)          54912
#
#  dropout_16 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_8 (Batc  (None, 400, 128)         512
#  hNormalization)
#
#  gru_13 (GRU)                (None, 400, 64)           37248
#
#  dropout_17 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_9 (Batc  (None, 400, 64)          256
#  hNormalization)
#
#  gru_14 (GRU)                (None, 32)                9408
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 56s 105ms/step - loss: 0.6889 - accuracy: 0.5874 - val_loss: 0.8777 - val_accuracy: 2.7632e-04
# Epoch 2/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.6679 - accuracy: 0.6213 - val_loss: 0.8870 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.6641 - accuracy: 0.6251 - val_loss: 0.9305 - val_accuracy: 2.7632e-04
# Epoch 4/100
# 453/453 [==============================] - 51s 112ms/step - loss: 0.6628 - accuracy: 0.6249 - val_loss: 0.9480 - val_accuracy: 2.7632e-04
# Epoch 5/100
# 453/453 [==============================] - 46s 101ms/step - loss: 0.6622 - accuracy: 0.6251 - val_loss: 0.9531 - val_accuracy: 2.7632e-04
# Epoch 6/100
# 453/453 [==============================] - 45s 100ms/step - loss: 0.6620 - accuracy: 0.6250 - val_loss: 0.9643 - val_accuracy: 2.7632e-04
# Epoch 7/100
# 453/453 [==============================] - 58s 128ms/step - loss: 0.6620 - accuracy: 0.6251 - val_loss: 0.9742 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 453/453 [==============================] - 60s 133ms/step - loss: 0.6618 - accuracy: 0.6251 - val_loss: 0.9819 - val_accuracy: 2.7632e-04
# Epoch 9/100
# 453/453 [==============================] - 54s 118ms/step - loss: 0.6619 - accuracy: 0.6251 - val_loss: 0.9875 - val_accuracy: 2.7632e-04
# Epoch 10/100
# 453/453 [==============================] - 58s 129ms/step - loss: 0.6617 - accuracy: 0.6250 - val_loss: 0.9793 - val_accuracy: 2.7632e-04
# Epoch 11/100
# 453/453 [==============================] - 61s 136ms/step - loss: 0.6617 - accuracy: 0.6250 - val_loss: 0.9932 - val_accuracy: 2.7632e-04
# Test Loss: 0.7077
# Test Accuracy: 0.4998
# 283/283 [==============================] - 9s 32ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4524
#            1       1.00      0.94      0.97      4523
#
#     accuracy                           0.97      9047
#    macro avg       0.97      0.97      0.97      9047
# weighted avg       0.97      0.97      0.97      9047
#
#
# Confusion Matrix:
# [[4519    5]
#  [ 251 4272]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.3),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)

# Compile the model
rnn_model.compile(optimizer=Adam(learning_rate=0.005), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_18 (GRU)                (None, 400, 128)          54912
#
#  dropout_24 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_12 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  gru_19 (GRU)                (None, 400, 64)           37248
#
#  dropout_25 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_13 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  gru_20 (GRU)                (None, 32)                9408
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params:
# Epoch 39/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.0928 - accuracy: 0.9667 - val_loss: 0.3709 - val_accuracy: 0.8954
# Epoch 40/100
# 453/453 [==============================] - 59s 129ms/step - loss: 0.1470 - accuracy: 0.9446 - val_loss: 0.0973 - val_accuracy: 0.9761
# Test Loss: 0.2018
# Test Accuracy: 0.9404
# 283/283 [==============================] - 11s 34ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94      4524
#            1       1.00      0.89      0.94      4523
#
#     accuracy                           0.94      9047
#    macro avg       0.95      0.94      0.94      9047
# weighted avg       0.95      0.94      0.94      9047
#
#
# Confusion Matrix:
# [[4505   19]
#  [ 520 4003]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.1),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.1),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.1),
        Dense(32, activation='relu'),
        Dropout(0.1),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)

# Compile the model
rnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_21 (GRU)                (None, 400, 128)          54912
#
#  dropout_28 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_14 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  gru_22 (GRU)                (None, 400, 64)           37248
#
#  dropout_29 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_15 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  gru_23 (GRU)                (None, 32)                9408
#
#  dropout_30 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 32)                1056
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 49s 94ms/step - loss: 0.6647 - accuracy: 0.6238 - val_loss: 0.9667 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 453/453 [==============================] - 45s 99ms/step - loss: 0.6638 - accuracy: 0.6249 - val_loss: 0.9718 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 453/453 [==============================] - 48s 105ms/step - loss: 0.5791 - accuracy: 0.7054 - val_loss: 0.5855 - val_accuracy: 0.7396
# Epoch 4/100
# 453/453 [==============================] - 49s 108ms/step - loss: 0.4007 - accuracy: 0.8300 - val_loss: 0.5367 - val_accuracy: 0.6822
# Epoch 5/100
# 453/453 [==============================] - 50s 111ms/step - loss: 0.3207 - accuracy: 0.8592 - val_loss: 0.8837 - val_accuracy: 0.6810
# Epoch 6/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.2738 - accuracy: 0.8789 - val_loss: 0.6012 - val_accuracy: 0.7432
# Epoch 7/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.2427 - accuracy: 0.8942 - val_loss: 0.1133 - val_accuracy: 0.9779
# Epoch 8/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.2140 - accuracy: 0.9072 - val_loss: 0.4971 - val_accuracy: 0.7567
# Epoch 9/100
# 453/453 [==============================] - 52s 115ms/step - loss: 0.1883 - accuracy: 0.9212 - val_loss: 0.1956 - val_accuracy: 0.9224
# Epoch 10/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.1689 - accuracy: 0.9280 - val_loss: 0.4496 - val_accuracy: 0.8263
# Epoch 11/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.1561 - accuracy: 0.9361 - val_loss: 0.7182 - val_accuracy: 0.7380
# Epoch 12/100
# 453/453 [==============================] - 52s 115ms/step - loss: 0.1390 - accuracy: 0.9436 - val_loss: 0.0881 - val_accuracy: 0.9743
# Epoch 13/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.1228 - accuracy: 0.9515 - val_loss: 0.0356 - val_accuracy: 0.9921
# Epoch 14/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.1156 - accuracy: 0.9543 - val_loss: 0.2252 - val_accuracy: 0.9232
# Epoch 15/100
# 453/453 [==============================] - 60s 133ms/step - loss: 0.1034 - accuracy: 0.9589 - val_loss: 0.0978 - val_accuracy: 0.9686
# Epoch 16/100
# 453/453 [==============================] - 52s 116ms/step - loss: 0.0958 - accuracy: 0.9643 - val_loss: 0.0887 - val_accuracy: 0.9736
# Epoch 17/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.0847 - accuracy: 0.9674 - val_loss: 0.2947 - val_accuracy: 0.8848
# Epoch 18/100
# 453/453 [==============================] - 60s 132ms/step - loss: 0.0775 - accuracy: 0.9717 - val_loss: 0.0839 - val_accuracy: 0.9746
# Epoch 19/100
# 453/453 [==============================] - 54s 119ms/step - loss: 0.0730 - accuracy: 0.9709 - val_loss: 0.1828 - val_accuracy: 0.9317
# Epoch 20/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.0667 - accuracy: 0.9752 - val_loss: 0.2729 - val_accuracy: 0.9096
# Epoch 21/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.0588 - accuracy: 0.9783 - val_loss: 0.3048 - val_accuracy: 0.9004
# Epoch 22/100
# 453/453 [==============================] - 55s 122ms/step - loss: 0.0591 - accuracy: 0.9785 - val_loss: 0.2675 - val_accuracy: 0.9094
# Epoch 23/100
# 453/453 [==============================] - 52s 115ms/step - loss: 0.0562 - accuracy: 0.9784 - val_loss: 0.0877 - val_accuracy: 0.9767
# Test Loss: 0.1791
# Test Accuracy: 0.9291
# 283/283 [==============================] - 12s 36ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      4524
#            1       0.99      0.87      0.92      4523
#
#     accuracy                           0.93      9047
#    macro avg       0.94      0.93      0.93      9047
# weighted avg       0.94      0.93      0.93      9047
#
#
# Confusion Matrix:
# [[4491   33]
#  [ 608 3915]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt


# Build RNN model
def build_rnn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(128, return_sequences=True, activation='tanh'),
        Dropout(0.2),
        BatchNormalization(),
        GRU(64, return_sequences=True, activation='tanh'),
        Dropout(0.2),
        BatchNormalization(),
        GRU(32, activation='tanh'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    return model

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])
rnn_model = build_rnn_model(input_shape)

# Compile the model
rnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# **Add model summary here**
rnn_model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = rnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = rnn_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Predictions and classification report
y_pred = (rnn_model.predict(X_test) > 0.5).astype(int).flatten()
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_24 (GRU)                (None, 400, 128)          54912
#
#  dropout_32 (Dropout)        (None, 400, 128)          0
#
#  batch_normalization_16 (Bat  (None, 400, 128)         512
#  chNormalization)
#
#  gru_25 (GRU)                (None, 400, 64)           37248
#
#  dropout_33 (Dropout)        (None, 400, 64)           0
#
#  batch_normalization_17 (Bat  (None, 400, 64)          256
#  chNormalization)
#
#  gru_26 (GRU)                (None, 32)                9408
#
#  dropout_34 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dropout_35 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 103,425
# Trainable params: 103,041
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 453/453 [==============================] - 55s 109ms/step - loss: 0.6669 - accuracy: 0.6222 - val_loss: 0.8843 - val_accuracy: 2.7632e-04
# Epoch 2/100
# 453/453 [==============================] - 52s 114ms/step - loss: 0.6648 - accuracy: 0.6249 - val_loss: 0.9674 - val_accuracy: 2.7632e-04
# Epoch 3/100
# 453/453 [==============================] - 48s 106ms/step - loss: 0.6631 - accuracy: 0.6250 - val_loss: 0.9386 - val_accuracy: 2.7632e-04
# Epoch 4/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.6630 - accuracy: 0.6250 - val_loss: 0.9437 - val_accuracy: 2.7632e-04
# Epoch 5/100
# 453/453 [==============================] - 58s 128ms/step - loss: 0.6622 - accuracy: 0.6249 - val_loss: 0.9751 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 453/453 [==============================] - 54s 120ms/step - loss: 0.6628 - accuracy: 0.6251 - val_loss: 1.0097 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 453/453 [==============================] - 51s 113ms/step - loss: 0.6626 - accuracy: 0.6250 - val_loss: 0.9371 - val_accuracy: 2.7632e-04
# Epoch 8/100
# 453/453 [==============================] - 58s 127ms/step - loss: 0.6609 - accuracy: 0.6252 - val_loss: 0.9588 - val_accuracy: 2.7632e-04
# Epoch 9/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.4872 - accuracy: 0.7772 - val_loss: 0.5441 - val_accuracy: 0.6545
# Epoch 10/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.3718 - accuracy: 0.8390 - val_loss: 0.9403 - val_accuracy: 0.5981
# Epoch 11/100
# 453/453 [==============================] - 57s 126ms/step - loss: 0.3328 - accuracy: 0.8572 - val_loss: 0.2664 - val_accuracy: 0.8602
# Epoch 12/100
# 453/453 [==============================] - 65s 144ms/step - loss: 0.3000 - accuracy: 0.8698 - val_loss: 0.2945 - val_accuracy: 0.8538
# Epoch 13/100
# 453/453 [==============================] - 63s 140ms/step - loss: 0.2757 - accuracy: 0.8808 - val_loss: 0.3199 - val_accuracy: 0.8495
# Epoch 14/100
# 453/453 [==============================] - 63s 140ms/step - loss: 0.2499 - accuracy: 0.8917 - val_loss: 0.3685 - val_accuracy: 0.8534
# Epoch 15/100
# 453/453 [==============================] - 65s 145ms/step - loss: 0.2288 - accuracy: 0.9032 - val_loss: 0.2937 - val_accuracy: 0.8646
# Epoch 16/100
# 453/453 [==============================] - 53s 117ms/step - loss: 0.2098 - accuracy: 0.9116 - val_loss: 0.2884 - val_accuracy: 0.8857
# Epoch 17/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.1920 - accuracy: 0.9195 - val_loss: 0.1569 - val_accuracy: 0.9450
# Epoch 18/100
# 453/453 [==============================] - 58s 128ms/step - loss: 0.1805 - accuracy: 0.9231 - val_loss: 0.2697 - val_accuracy: 0.8989
# Epoch 19/100
# 453/453 [==============================] - 52s 115ms/step - loss: 0.1693 - accuracy: 0.9303 - val_loss: 0.2870 - val_accuracy: 0.8870
# Epoch 20/100
# 453/453 [==============================] - 58s 129ms/step - loss: 0.1549 - accuracy: 0.9343 - val_loss: 0.0735 - val_accuracy: 0.9758
# Epoch 21/100
# 453/453 [==============================] - 60s 132ms/step - loss: 0.1458 - accuracy: 0.9417 - val_loss: 0.0290 - val_accuracy: 0.9932
# Epoch 22/100
# 453/453 [==============================] - 53s 116ms/step - loss: 0.1371 - accuracy: 0.9452 - val_loss: 0.1945 - val_accuracy: 0.9356
# Epoch 23/100
# 453/453 [==============================] - 56s 124ms/step - loss: 0.1260 - accuracy: 0.9513 - val_loss: 0.1901 - val_accuracy: 0.9258
# Epoch 24/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.1238 - accuracy: 0.9521 - val_loss: 0.0897 - val_accuracy: 0.9688
# Epoch 25/100
# 453/453 [==============================] - 53s 118ms/step - loss: 0.1097 - accuracy: 0.9578 - val_loss: 0.0298 - val_accuracy: 0.9928
# Epoch 26/100
# 453/453 [==============================] - 54s 120ms/step - loss: 0.1045 - accuracy: 0.9604 - val_loss: 0.2206 - val_accuracy: 0.9306
# Epoch 27/100
# 453/453 [==============================] - 60s 132ms/step - loss: 0.0956 - accuracy: 0.9623 - val_loss: 0.2110 - val_accuracy: 0.9290
# Epoch 28/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.0920 - accuracy: 0.9649 - val_loss: 0.0555 - val_accuracy: 0.9870
# Epoch 29/100
# 453/453 [==============================] - 55s 121ms/step - loss: 0.0870 - accuracy: 0.9668 - val_loss: 0.1975 - val_accuracy: 0.9255
# Epoch 30/100
# 453/453 [==============================] - 61s 134ms/step - loss: 0.0816 - accuracy: 0.9705 - val_loss: 0.1184 - val_accuracy: 0.9573
# Epoch 31/100
# 453/453 [==============================] - 59s 131ms/step - loss: 0.0797 - accuracy: 0.9711 - val_loss: 0.0649 - val_accuracy: 0.9784
# Test Loss: 0.2224
# Test Accuracy: 0.9133
# 283/283 [==============================] - 10s 31ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      4524
#            1       0.99      0.83      0.91      4523
#
#     accuracy                           0.91      9047
#    macro avg       0.92      0.91      0.91      9047
# weighted avg       0.92      0.91      0.91      9047
#
#
# Confusion Matrix:
# [[4500   24]
#  [ 760 3763]]
