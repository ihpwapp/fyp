# %%
import glob
import os
import librosa
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit
import tensorflow as tf
from tensorflow.keras import layers, models

# Path to the metadata file
metadata_file_path = r'D:\download\Compressed\DF-keys-full\keys\DF\CM\trial_metadata.txt'

# Dictionary to hold file identifiers and labels
labels = {}

# Open and read the metadata file
with open(metadata_file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        file_identifier = parts[1]  # Example: DF_E_2000011
        label = parts[5]            # Example: "spoof"
        labels[file_identifier] = label

# Directory containing the undersampled audio files
undersampled_audio_dir = r'D:\audio_files\undersampled_audio'


# Find all .flac files in the undersampled directory
audio_files = glob.glob(os.path.join(undersampled_audio_dir, '*.flac'))

# Create a list to store only those files that have corresponding labels in the metadata
valid_audio_files = []
valid_labels = []

# Loop through the audio files and match with metadata labels
for audio_file in audio_files:
    file_name = os.path.basename(audio_file)
    file_identifier = file_name.split('.')[0]  # Extract the file identifier (before the extension)

    # Check if the file identifier exists in the metadata labels
    if file_identifier in labels:
        valid_audio_files.append(audio_file)  # Keep this audio file
        valid_labels.append(labels[file_identifier])  # Store the corresponding label (spoof/bonafide)

# Print the number of matching files
print(f"Found {len(valid_audio_files)} audio files with corresponding labels.")

# Audio to MFCC conversion function
def audio_to_mfcc(audio_file, sr=22050, n_mfcc=13):
    """Convert audio to MFCC."""
    audio, sample_rate = librosa.load(audio_file, sr=sr)
    mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    return mfcc

# Resize the MFCC to a fixed size function
def resize_spectrogram(spectrogram, target_size=(128, 128)):
    """Resize the MFCC to a fixed size."""
    return cv2.resize(spectrogram, target_size)

# Preprocessing the audio files
def preprocess_audio_files(audio_files, labels, target_size=(128, 128)):
    """Convert audio files to MFCCs, resize, and normalize them."""
    mfcc_data = []
    label_data = []

    for audio_file, label in zip(audio_files, labels):
        mfcc = audio_to_mfcc(audio_file)
        resized_mfcc = resize_spectrogram(mfcc, target_size)
        
        # Safe normalization: Check if the max value is 0
        max_value = np.max(resized_mfcc)
        if max_value > 0:
            normalized_mfcc = resized_mfcc / max_value
        else:
            normalized_mfcc = resized_mfcc  # Leave it as is if the max is 0

        mfcc_data.append(normalized_mfcc)
        label_data.append(1 if label == 'spoof' else 0)  # Binary label (1: spoof, 0: bonafide)

    return np.array(mfcc_data), np.array(label_data)

# Preprocess the valid audio files and labels
X, y = preprocess_audio_files(valid_audio_files, valid_labels, target_size=(128, 128
                                                                            ))

# Add a channel dimension for CNN
X = np.expand_dims(X, axis=-1)
# Out:
# Found 45234 audio files with corresponding labels.

# %%
# Stratified 70:30 train-test split
def stratified_split_70_30(X, y, test_size=0.2, random_state=42):
    """Split dataset into stratified 70/30 sets."""
    strat_split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    
    for train_idx, test_idx in strat_split.split(X, y):
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]
    
    # Ensure that the training set has balanced classes
    class_counts = np.bincount(y_train)
    min_class_count = min(class_counts)
    spoof_indices = np.where(y_train == 1)[0][:min_class_count]
    bonafide_indices = np.where(y_train == 0)[0][:min_class_count]
    balanced_train_indices = np.concatenate([spoof_indices, bonafide_indices])
    X_train_balanced, y_train_balanced = X_train[balanced_train_indices], y_train[balanced_train_indices]

    return X_train_balanced, X_test, y_train_balanced, y_test

# Perform the stratified 80/30 split
X_train, X_test, y_train, y_test = stratified_split_70_30(X, y, test_size=0.2, random_state=42)

# Print the distribution of classes to verify stratification
print(f"Training set distribution: {np.bincount(y_train)}")
print(f"Test set distribution: {np.bincount(y_test)}")
# Out:
# Training set distribution: [18093 18093]
# Test set distribution: [4524 4523]

# %%
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define the CNN architecture
def build_cnn(input_shape):
    model = models.Sequential()
    
    # 1st Convolutional Layer
    model.add(layers.Conv2D(16, kernel_size=(3, 3), input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(LeakyReLU(alpha=0.01))

    # 2nd Convolutional Layer
    model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(LeakyReLU(alpha=0.01))

    # 3rd Convolutional Layer
    model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(LeakyReLU(alpha=0.01))

    # Flatten the output and add fully connected layers
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.4))

    # Output layer (binary classification)
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(optimizer='AdamW', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model
# Create the model with the modified parameters
input_shape = (128, 128, 1)  # Shape of input (height, width, channels)
model = build_cnn(input_shape)

# Print model summary
model.summary()

# Set up early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# Train the model with early stopping, using the RGB data
history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.2f}")

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# d:\download\fyp\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# d:\download\fyp\.venv\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 126, 126, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 63, 63, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 63, 63, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 61, 61, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     1,605,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,629,185 (6.21 MB)
#  Trainable params: 1,629,185 (6.21 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 108s 185ms/step - accuracy: 0.7605 - loss: 0.4993 - val_accuracy: 0.8367 - val_loss: 0.3587
# Epoch 2/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 96s 169ms/step - accuracy: 0.8395 - loss: 0.3454 - val_accuracy: 0.8876 - val_loss: 0.2361
# Epoch 3/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 96s 169ms/step - accuracy: 0.9015 - loss: 0.2271 - val_accuracy: 0.9454 - val_loss: 0.1475
# Epoch 4/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 97s 171ms/step - accuracy: 0.9420 - loss: 0.1391 - val_accuracy: 0.9637 - val_loss: 0.1054
# Epoch 5/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 113s 200ms/step - accuracy: 0.9625 - loss: 0.0941 - val_accuracy: 0.9729 - val_loss: 0.0854
# Epoch 6/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 99s 174ms/step - accuracy: 0.9707 - loss: 0.0717 - val_accuracy: 0.9717 - val_loss: 0.0738
# Epoch 7/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 152ms/step - accuracy: 0.9715 - loss: 0.0708 - val_accuracy: 0.9796 - val_loss: 0.0678
# Epoch 8/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 151ms/step - accuracy: 0.9814 - loss: 0.0449 - val_accuracy: 0.9808 - val_loss: 0.0593
# Epoch 9/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 85s 151ms/step - accuracy: 0.9822 - loss: 0.0450 - val_accuracy: 0.9801 - val_loss: 0.0687
# Epoch 10/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 91s 160ms/step - accuracy: 0.9814 - loss: 0.0449 - val_accuracy: 0.9654 - val_loss: 0.1095
# Epoch 11/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 85s 151ms/step - accuracy: 0.9837 - loss: 0.0417 - val_accuracy: 0.9814 - val_loss: 0.0648
# Epoch 12/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 151ms/step - accuracy: 0.9851 - loss: 0.0352 - val_accuracy: 0.9813 - val_loss: 0.0685
# Epoch 13/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 152ms/step - accuracy: 0.9866 - loss: 0.0332 - val_accuracy: 0.9813 - val_loss: 0.0684
# Epoch 14/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 151ms/step - accuracy: 0.9873 - loss: 0.0338 - val_accuracy: 0.9840 - val_loss: 0.0569
# Epoch 15/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 152ms/step - accuracy: 0.9854 - loss: 0.0379 - val_accuracy: 0.9823 - val_loss: 0.0649
# Epoch 16/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 152ms/step - accuracy: 0.9877 - loss: 0.0306 - val_accuracy: 0.9769 - val_loss: 0.1163
# Epoch 17/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 90s 159ms/step - accuracy: 0.9898 - loss: 0.0249 - val_accuracy: 0.9766 - val_loss: 0.0769
# Epoch 18/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 89s 157ms/step - accuracy: 0.9887 - loss: 0.0294 - val_accuracy: 0.9772 - val_loss: 0.1050
# Epoch 19/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 87s 155ms/step - accuracy: 0.9878 - loss: 0.0326 - val_accuracy: 0.9841 - val_loss: 0.0618
# Epoch 20/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 87s 154ms/step - accuracy: 0.9896 - loss: 0.0271 - val_accuracy: 0.9847 - val_loss: 0.0666
# Epoch 21/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 90s 158ms/step - accuracy: 0.9901 - loss: 0.0254 - val_accuracy: 0.9735 - val_loss: 0.1236
# Epoch 22/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 88s 156ms/step - accuracy: 0.9915 - loss: 0.0210 - val_accuracy: 0.9849 - val_loss: 0.0693
# Epoch 23/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 86s 152ms/step - accuracy: 0.9891 - loss: 0.0273 - val_accuracy: 0.9818 - val_loss: 0.0711
# Epoch 24/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 100s 177ms/step - accuracy: 0.9908 - loss: 0.0237 - val_accuracy: 0.9849 - val_loss: 0.0736
# Epoch 25/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9923 - loss: 0.0209 - val_accuracy: 0.9912 - val_loss: 0.0451
# Epoch 26/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9918 - loss: 0.0228 - val_accuracy: 0.9846 - val_loss: 0.0817
# Epoch 27/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9926 - loss: 0.0203 - val_accuracy: 0.9830 - val_loss: 0.0792
# Epoch 28/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9916 - loss: 0.0218 - val_accuracy: 0.9891 - val_loss: 0.0470
# Epoch 29/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9925 - loss: 0.0208 - val_accuracy: 0.9865 - val_loss: 0.0653
# Epoch 30/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 197ms/step - accuracy: 0.9918 - loss: 0.0224 - val_accuracy: 0.9847 - val_loss: 0.0816
# Epoch 31/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9922 - loss: 0.0207 - val_accuracy: 0.9839 - val_loss: 0.0910
# Epoch 32/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 193ms/step - accuracy: 0.9929 - loss: 0.0184 - val_accuracy: 0.9845 - val_loss: 0.0645
# Epoch 33/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 116s 205ms/step - accuracy: 0.9919 - loss: 0.0186 - val_accuracy: 0.9860 - val_loss: 0.0670
# Epoch 34/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 114s 202ms/step - accuracy: 0.9930 - loss: 0.0192 - val_accuracy: 0.9829 - val_loss: 0.0758
# Epoch 35/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9938 - loss: 0.0151 - val_accuracy: 0.9834 - val_loss: 0.0928
# Epoch 36/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9935 - loss: 0.0165 - val_accuracy: 0.9797 - val_loss: 0.1020
# Epoch 37/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9935 - loss: 0.0182 - val_accuracy: 0.9797 - val_loss: 0.0979
# Epoch 38/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9942 - loss: 0.0167 - val_accuracy: 0.9875 - val_loss: 0.0577
# Epoch 39/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9944 - loss: 0.0159 - val_accuracy: 0.9871 - val_loss: 0.0538
# Epoch 40/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9941 - loss: 0.0160 - val_accuracy: 0.9845 - val_loss: 0.0783
# Epoch 41/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9933 - loss: 0.0170 - val_accuracy: 0.9873 - val_loss: 0.0640
# Epoch 42/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9942 - loss: 0.0160 - val_accuracy: 0.9864 - val_loss: 0.0638
# Epoch 43/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9944 - loss: 0.0146 - val_accuracy: 0.9825 - val_loss: 0.0790
# Epoch 44/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9949 - loss: 0.0141 - val_accuracy: 0.9840 - val_loss: 0.0824
# Epoch 45/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9946 - loss: 0.0138 - val_accuracy: 0.9886 - val_loss: 0.0552
# Epoch 46/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.9903 - val_loss: 0.0600
# Epoch 47/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9949 - loss: 0.0142 - val_accuracy: 0.9813 - val_loss: 0.0921
# Epoch 48/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9954 - loss: 0.0135 - val_accuracy: 0.9859 - val_loss: 0.0742
# Epoch 49/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9951 - loss: 0.0139 - val_accuracy: 0.9828 - val_loss: 0.0826
# Epoch 50/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9936 - loss: 0.0182 - val_accuracy: 0.9862 - val_loss: 0.0683
# Epoch 51/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9945 - loss: 0.0148 - val_accuracy: 0.9883 - val_loss: 0.0599
# Epoch 52/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9960 - loss: 0.0119 - val_accuracy: 0.9852 - val_loss: 0.0785
# Epoch 53/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9943 - loss: 0.0164 - val_accuracy: 0.9851 - val_loss: 0.0852
# Epoch 54/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9873 - val_loss: 0.0779
# Epoch 55/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9946 - loss: 0.0143 - val_accuracy: 0.9884 - val_loss: 0.0498
# Epoch 56/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9950 - loss: 0.0146 - val_accuracy: 0.9802 - val_loss: 0.1162
# Epoch 57/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9952 - loss: 0.0132 - val_accuracy: 0.9874 - val_loss: 0.0874
# Epoch 58/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.9847 - val_loss: 0.0960
# Epoch 59/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9949 - loss: 0.0134 - val_accuracy: 0.9873 - val_loss: 0.0729
# Epoch 60/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9951 - loss: 0.0120 - val_accuracy: 0.9841 - val_loss: 0.0775
# Epoch 61/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9954 - loss: 0.0139 - val_accuracy: 0.9865 - val_loss: 0.0810
# Epoch 62/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9953 - loss: 0.0115 - val_accuracy: 0.9831 - val_loss: 0.1013
# Epoch 63/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9952 - loss: 0.0127 - val_accuracy: 0.9872 - val_loss: 0.0687
# Epoch 64/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9958 - loss: 0.0115 - val_accuracy: 0.9870 - val_loss: 0.1018
# Epoch 65/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9953 - loss: 0.0133 - val_accuracy: 0.9826 - val_loss: 0.0812
# Epoch 66/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9960 - loss: 0.0116 - val_accuracy: 0.9871 - val_loss: 0.0732
# Epoch 67/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9958 - loss: 0.0119 - val_accuracy: 0.9867 - val_loss: 0.0637
# Epoch 68/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9959 - loss: 0.0111 - val_accuracy: 0.9851 - val_loss: 0.0832
# Epoch 69/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9956 - loss: 0.0122 - val_accuracy: 0.9836 - val_loss: 0.1000
# Epoch 70/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9953 - loss: 0.0143 - val_accuracy: 0.9871 - val_loss: 0.0853
# Epoch 71/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9958 - loss: 0.0115 - val_accuracy: 0.9870 - val_loss: 0.0957
# Epoch 72/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 197ms/step - accuracy: 0.9943 - loss: 0.0146 - val_accuracy: 0.9896 - val_loss: 0.0607
# Epoch 73/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9963 - loss: 0.0101 - val_accuracy: 0.9847 - val_loss: 0.1029
# Epoch 74/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9962 - loss: 0.0104 - val_accuracy: 0.9849 - val_loss: 0.0970
# Epoch 75/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9959 - loss: 0.0104 - val_accuracy: 0.9885 - val_loss: 0.0665
# Epoch 76/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9972 - loss: 0.0089 - val_accuracy: 0.9855 - val_loss: 0.0623
# Epoch 77/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 192ms/step - accuracy: 0.9958 - loss: 0.0120 - val_accuracy: 0.9875 - val_loss: 0.0906
# Epoch 78/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 192ms/step - accuracy: 0.9965 - loss: 0.0097 - val_accuracy: 0.9831 - val_loss: 0.1205
# Epoch 79/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 192ms/step - accuracy: 0.9960 - loss: 0.0125 - val_accuracy: 0.9885 - val_loss: 0.0582
# Epoch 80/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 193ms/step - accuracy: 0.9960 - loss: 0.0106 - val_accuracy: 0.9844 - val_loss: 0.1216
# Epoch 81/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 193ms/step - accuracy: 0.9963 - loss: 0.0092 - val_accuracy: 0.9838 - val_loss: 0.1028
# Epoch 82/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 193ms/step - accuracy: 0.9971 - loss: 0.0093 - val_accuracy: 0.9864 - val_loss: 0.0758
# Epoch 83/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 109s 192ms/step - accuracy: 0.9969 - loss: 0.0105 - val_accuracy: 0.9841 - val_loss: 0.0776
# Epoch 84/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9960 - loss: 0.0103 - val_accuracy: 0.9857 - val_loss: 0.0892
# Epoch 85/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 197ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.9846 - val_loss: 0.0945
# Epoch 86/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9959 - loss: 0.0110 - val_accuracy: 0.9878 - val_loss: 0.0743
# Epoch 87/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.9843 - val_loss: 0.0839
# Epoch 88/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9882 - val_loss: 0.0852
# Epoch 89/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9964 - loss: 0.0103 - val_accuracy: 0.9859 - val_loss: 0.0920
# Epoch 90/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9970 - loss: 0.0085 - val_accuracy: 0.9877 - val_loss: 0.0927
# Epoch 91/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9962 - loss: 0.0105 - val_accuracy: 0.9887 - val_loss: 0.0766
# Epoch 92/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9970 - loss: 0.0096 - val_accuracy: 0.9817 - val_loss: 0.1295
# Epoch 93/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9829 - val_loss: 0.1239
# Epoch 94/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9976 - loss: 0.0065 - val_accuracy: 0.9896 - val_loss: 0.0765
# Epoch 95/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9888 - val_loss: 0.0663
# Epoch 96/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 196ms/step - accuracy: 0.9962 - loss: 0.0114 - val_accuracy: 0.9891 - val_loss: 0.0613
# Epoch 97/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9968 - loss: 0.0085 - val_accuracy: 0.9889 - val_loss: 0.0666
# Epoch 98/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 111s 195ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9847 - val_loss: 0.0966
# Epoch 99/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 195ms/step - accuracy: 0.9963 - loss: 0.0094 - val_accuracy: 0.9896 - val_loss: 0.0563
# Epoch 100/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 110s 194ms/step - accuracy: 0.9971 - loss: 0.0080 - val_accuracy: 0.9855 - val_loss: 0.0847
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.9908 - loss: 0.0438
# Test accuracy: 0.99

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score

# Predict the probability scores on the test set
y_pred_prob = model.predict(X_test).ravel()  # Flatten the array for binary classification
y_pred_class = (y_pred_prob >= 0.5).astype(int)   # Convert probabilities to binary classes (0 or 1)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_class)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Bonafide', 'Spoof'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score
precision = precision_score(y_test, y_pred_class)
recall = recall_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

# Print precision, recall, and F1 score
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Compute the ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# d:\download\fyp\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model.save('.99.keras')
